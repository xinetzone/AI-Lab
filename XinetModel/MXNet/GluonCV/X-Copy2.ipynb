# %%
import sys
sys.path.append('E:/zlab/')
from loader import Loader
# ----------------

import time
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import tables as tb
import mxnet as mx
from mxnet import nd, autograd, gluon
import gluonbook as gb
from mxnet import gluon, init, nd
from mxnet.gluon import data as gdata, loss as gloss, model_zoo, nn
from sklearn.semi_supervised.label_propagation import LabelSpreading
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, accuracy_score
from mxboard import SummaryWriter
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # 载入数据

# %%
import tables as tb

h5 = tb.open_file('E:/xdata/X.h5')
#h5 = tb.open_file('./X.h5')

data = h5.root.cifar10

# %% [markdown]
# ## 划分数据集

# %%
from sklearn.model_selection import train_test_split

X = data.trainX[:]
y = data.trainY[:]
X_train, X_unlabel, y_train, y_unlabel = train_test_split(
    X, y, test_size=0.98, random_state=42)

batch_size = 32
trainset = Loader(batch_size, X_train, y_train, shuffle=True, name='train')
testset = Loader(
    batch_size, data.testX, data.testY, shuffle=False, name='test')
unlabelset = Loader(
    batch_size,
    X_unlabel[:10000],
    y_unlabel[:10000],
    shuffle=False,
    name='agent')

# %%
for imgs, labels in iter(trainset):
    trainset.show_imgs(data.label_names, imgs.astype(np.uint8), labels)
    break

# %% [markdown]
# # 模型的配置

# %%
class SemiModel(nn.HybridBlock):
    def __init__(self, features, **kwargs):
        super().__init__(**kwargs)
        self.features = features
        self.output = nn.Dense(10)
        
    def hybrid_forward(self, F, x):
        x = self.features(x)
        return self.output(x)

pretrain_net = model_zoo.vision.resnet50_v2(pretrained=False)
net = SemiModel(pretrain_net.features)

# 网络预设
_net = model_zoo.vision.resnet50_v2(pretrained=True)
net.features = _net.features
#net.features.add(nn.Flatten())
#net.features[-1].initialize(init.Xavier(magnitude=2.24))
net.output.initialize(init.Xavier(magnitude=2.24))

# %% [markdown]
# # 模型超参数设定

# %%
from xtrain import XModel

# 超参数设定
epochs = 500
learning_rate = 0.1
model = XModel(learning_rate)
ctx = model.ctx
print('training on', ctx)
net.collect_params().reset_ctx(ctx)
net.hybridize()
# Out:
# training on gpu(0)

# %% [markdown]
# # 数据打包

# %%
class DataLoader(dict):
    def __init__(self, ctx, batch_size, trainset, unlabelset, *args, **kwargs):
        '''
        初始化数据迭代器和标签传播算法
        '''
        self.__dict__ = self
        self.ctx = ctx
        self.train = trainset
        self.unlabel = unlabelset
        self.X_l = Loader(
            batch_size, self.train.X, shuffle=False, name='x_train')
        self.X_u = Loader(
            batch_size, self.unlabel.X, shuffle=False, name='x_test')
        self.features_u = self.unlabel.X.reshape((-1, 32 * 32 * 3))
        self.features_l = self.train.X.reshape((-1, 32 * 32 * 3))
        _min_max_scaler = MinMaxScaler()
        self.features_l = _min_max_scaler.fit_transform(self.features_l)
        self.features_u = _min_max_scaler.transform(self.features_u)
        self.y_agent = -np.ones_like(self.unlabel.Y)
        self._lbp = LabelSpreading(gamma=0.025, n_jobs=-1, max_iter=100)
        self.ssl()

    def ssl(self):
        '''
        标签传播
        '''
        X = np.concatenate([self.features_l, self.features_u])
        y_ = np.concatenate([trainset.Y, self.y_agent])
        self._lbp.fit(X, y_)  # 必须将 X 缩放到 [0,1]
        self.y_hats = self._lbp.transduction_[self.train.Y.shape[0]:]
        print('分类指标：')
        print(classification_report(self.unlabel.Y, self.y_hats))

    def get_features(self, net, data_iter):
        for x in data_iter:
            x = nd.array(x, ctx=self.ctx).transpose((0, 3, 1, 2))
            features = net.features(x)
            yield features

    def agent(self, net):
        '''
        net:: 神经网络
        inference::输出 net 的 features
        '''
        # 提取有标签数据的特征
        self.features_l = np.concatenate(
            [f.asnumpy() for f in dataset.get_features(net, dataset.X_l)])
        # 提取无标签数据的特征
        self.features_u = np.concatenate(
            [f.asnumpy() for f in dataset.get_features(net, dataset.X_u)])
        self.ssl()
        self.agency_acc = accuracy_score(dataset.unlabel.Y, self.y_hats)

dataset = DataLoader(ctx, batch_size, trainset, unlabelset)
# Out:
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.32      0.48      0.38       973
#           1       0.50      0.15      0.23       979
#           2       0.29      0.09      0.14      1030
#           3       0.29      0.03      0.05      1023
#           4       0.20      0.44      0.27       933
#           5       0.36      0.21      0.26      1015
#           6       0.23      0.55      0.32       996
#           7       0.58      0.13      0.22       994
#           8       0.31      0.64      0.42      1017
#           9       0.52      0.23      0.32      1040
#
# avg / total       0.36      0.29      0.26     10000

# %% [markdown]
# # 训练和调优

# %%
logdir = 'D:/graph/'
sw = SummaryWriter(logdir, flush_secs=5)  # 可视化
y_pre = dataset.y_hats  # 微调前的预测标签
dataset.agent(net)
epoch = 1
while epoch < 500:
    print('微调有标签数据')
    print('~_~' * 25)
    sw.add_scalar('accuracy_curves',
                  {unlabelset.name + '_SSL': dataset.agency_acc}, epoch)
    net = model.train(net, dataset.train, testset, epochs=10, start=epoch)
    dataset.agent(net)
    print(unlabelset.name + '_SSL: ', dataset.agency_acc)
    epoch += 10
    X_u_set = Loader(
            batch_size,
            dataset.unlabel.X,
            dataset.y_hats,
            shuffle=True,
            name='train_agent')
    print('-_' * 50)
    print('微调带有代理标签数据')
    net = model.train(net, X_u_set, testset, epochs=1, start=epoch)
    dataset.agent(net)
    epoch += 1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\semi_supervised\label_propagation.py:293: RuntimeWarning: invalid value encountered in true_divide
#   self.label_distributions_ /= normalizer
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.11      0.53      0.18       973
#           1       0.18      0.09      0.12       979
#           2       0.19      0.13      0.16      1030
#           3       0.14      0.07      0.09      1023
#           4       0.22      0.19      0.21       933
#           5       0.22      0.09      0.13      1015
#           6       0.26      0.19      0.22       996
#           7       0.20      0.14      0.16       994
#           8       0.35      0.23      0.28      1017
#           9       0.21      0.07      0.11      1040
#
# avg / total       0.21      0.17      0.17     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 1, loss 4.11782, train acc 0.105, test_acc 0.1, time 19.3 sec
# Epoch 2, loss 2.45778, train acc 0.145, test_acc 0.1, time 18.1 sec
# Epoch 3, loss 2.14967, train acc 0.186, test_acc 0.1537, time 17.7 sec
# Epoch 4, loss 1.92905, train acc 0.224, test_acc 0.221, time 17.6 sec
# Epoch 5, loss 1.83448, train acc 0.287, test_acc 0.2314, time 17.3 sec
# Epoch 6, loss 1.78885, train acc 0.311, test_acc 0.2669, time 16.5 sec
# Epoch 7, loss 1.85574, train acc 0.294, test_acc 0.206, time 16.8 sec
# Epoch 8, loss 1.89942, train acc 0.273, test_acc 0.2325, time 17.3 sec
# Epoch 9, loss 1.92729, train acc 0.264, test_acc 0.2371, time 16.5 sec
# Epoch 10, loss 1.9553, train acc 0.3, test_acc 0.2471, time 16.6 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.25      0.25      0.25       973
#           1       0.20      0.20      0.20       979
#           2       0.14      0.13      0.13      1030
#           3       0.12      0.08      0.09      1023
#           4       0.14      0.20      0.17       933
#           5       0.21      0.23      0.22      1015
#           6       0.16      0.22      0.18       996
#           7       0.14      0.12      0.13       994
#           8       0.29      0.29      0.29      1017
#           9       0.19      0.14      0.16      1040
#
# avg / total       0.18      0.18      0.18     10000
#
# agent_SSL:  0.1845
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 11, loss 2.13147, train acc 0.2167, test_acc 0.101, time 59.1 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.16      0.49      0.24       973
#           1       0.11      0.04      0.06       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.12      0.21      0.15       933
#           5       0.14      0.22      0.17      1015
#           6       0.18      0.43      0.25       996
#           7       0.00      0.00      0.00       994
#           8       0.22      0.22      0.22      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.09      0.16      0.11     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Epoch 12, loss 2.17095, train acc 0.172, test_acc 0.1749, time 16.3 sec
# Epoch 13, loss 2.16539, train acc 0.172, test_acc 0.1559, time 17.1 sec
# Epoch 14, loss 2.16994, train acc 0.175, test_acc 0.1253, time 16.3 sec
# Epoch 15, loss 2.16054, train acc 0.171, test_acc 0.159, time 17.4 sec
# Epoch 16, loss 2.15892, train acc 0.182, test_acc 0.1649, time 17.1 sec
# Epoch 17, loss 2.15746, train acc 0.188, test_acc 0.1759, time 16.7 sec
# Epoch 18, loss 2.15681, train acc 0.178, test_acc 0.1731, time 17.2 sec
# Epoch 19, loss 2.15332, train acc 0.176, test_acc 0.1827, time 18.1 sec
# Epoch 20, loss 2.15124, train acc 0.178, test_acc 0.1662, time 17.2 sec
# Epoch 21, loss 2.15482, train acc 0.178, test_acc 0.1689, time 17.1 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 22, loss 0.186921, train acc 0.9962, test_acc 0.1, time 62.5 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 23, loss 2.47221, train acc 0.112, test_acc 0.1, time 17.6 sec
# Epoch 24, loss 2.25243, train acc 0.112, test_acc 0.1, time 17.5 sec
# Epoch 25, loss 2.24842, train acc 0.112, test_acc 0.1, time 18.3 sec
# Epoch 26, loss 2.24846, train acc 0.112, test_acc 0.1, time 17.7 sec
# Epoch 27, loss 2.24814, train acc 0.108, test_acc 0.1, time 17.8 sec
# Epoch 28, loss 2.24859, train acc 0.099, test_acc 0.1, time 17.2 sec
# Epoch 29, loss 2.24861, train acc 0.089, test_acc 0.1, time 17.1 sec
# Epoch 30, loss 2.24842, train acc 0.112, test_acc 0.1, time 17.3 sec
# Epoch 31, loss 2.24836, train acc 0.107, test_acc 0.1, time 17.5 sec
# Epoch 32, loss 2.24833, train acc 0.109, test_acc 0.1, time 17.1 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 33, loss 0.296076, train acc 1, test_acc 0.1, time 60.0 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 34, loss 2.48193, train acc 0.112, test_acc 0.1, time 17.1 sec
# Epoch 35, loss 2.25406, train acc 0.112, test_acc 0.1, time 17.2 sec
# Epoch 36, loss 2.24888, train acc 0.112, test_acc 0.1, time 17.0 sec
# Epoch 37, loss 2.24847, train acc 0.112, test_acc 0.1, time 17.0 sec
# Epoch 38, loss 2.24831, train acc 0.112, test_acc 0.1, time 17.0 sec
# Epoch 39, loss 2.24846, train acc 0.11, test_acc 0.1, time 16.7 sec
# Epoch 40, loss 2.24844, train acc 0.104, test_acc 0.1, time 16.9 sec
# Epoch 41, loss 2.24857, train acc 0.112, test_acc 0.1, time 16.8 sec
# Epoch 42, loss 2.24862, train acc 0.109, test_acc 0.1, time 17.1 sec
# Epoch 43, loss 2.24815, train acc 0.109, test_acc 0.1, time 17.0 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 44, loss 0.301711, train acc 1, test_acc 0.1, time 59.6 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 45, loss 2.47834, train acc 0.112, test_acc 0.1, time 16.7 sec
# Epoch 46, loss 2.2542, train acc 0.112, test_acc 0.1, time 17.0 sec
# Epoch 47, loss 2.24879, train acc 0.112, test_acc 0.1, time 16.8 sec
# Epoch 48, loss 2.24829, train acc 0.112, test_acc 0.1, time 17.6 sec
# Epoch 49, loss 2.24836, train acc 0.112, test_acc 0.1, time 17.3 sec
# Epoch 50, loss 2.24824, train acc 0.112, test_acc 0.1, time 17.4 sec
# Epoch 51, loss 2.24857, train acc 0.102, test_acc 0.1, time 17.8 sec
# Epoch 52, loss 2.24824, train acc 0.107, test_acc 0.1, time 17.1 sec
# Epoch 53, loss 2.2485, train acc 0.107, test_acc 0.1, time 17.1 sec
# Epoch 54, loss 2.24846, train acc 0.098, test_acc 0.1, time 17.4 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 55, loss 0.302518, train acc 1, test_acc 0.1, time 58.3 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 56, loss 2.49189, train acc 0.112, test_acc 0.1, time 17.1 sec
# Epoch 57, loss 2.25307, train acc 0.112, test_acc 0.1, time 16.8 sec
# Epoch 58, loss 2.2485, train acc 0.112, test_acc 0.1, time 16.6 sec
# Epoch 59, loss 2.24811, train acc 0.112, test_acc 0.1, time 16.8 sec
# Epoch 60, loss 2.24835, train acc 0.104, test_acc 0.1, time 17.5 sec
# Epoch 61, loss 2.24846, train acc 0.109, test_acc 0.1, time 16.7 sec
# Epoch 62, loss 2.24854, train acc 0.112, test_acc 0.1, time 17.2 sec
# Epoch 63, loss 2.24835, train acc 0.109, test_acc 0.1, time 16.3 sec
# Epoch 64, loss 2.24877, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 65, loss 2.24843, train acc 0.104, test_acc 0.1, time 17.7 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 66, loss 0.3029, train acc 1, test_acc 0.1, time 59.7 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 67, loss 2.48667, train acc 0.112, test_acc 0.1, time 16.8 sec
# Epoch 68, loss 2.25499, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 69, loss 2.24901, train acc 0.112, test_acc 0.1, time 16.8 sec
# Epoch 70, loss 2.24821, train acc 0.112, test_acc 0.1, time 17.2 sec
# Epoch 71, loss 2.24844, train acc 0.109, test_acc 0.1, time 17.4 sec
# Epoch 72, loss 2.24804, train acc 0.106, test_acc 0.1, time 16.3 sec
# Epoch 73, loss 2.24815, train acc 0.112, test_acc 0.1, time 16.7 sec
# Epoch 74, loss 2.24834, train acc 0.112, test_acc 0.1, time 17.2 sec
# Epoch 75, loss 2.24834, train acc 0.109, test_acc 0.1, time 16.4 sec
# Epoch 76, loss 2.24844, train acc 0.112, test_acc 0.1, time 16.5 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 77, loss 0.303263, train acc 0.9968, test_acc 0.1, time 63.1 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 78, loss 2.48199, train acc 0.112, test_acc 0.1, time 18.7 sec
# Epoch 79, loss 2.2534, train acc 0.112, test_acc 0.1, time 17.6 sec
# Epoch 80, loss 2.2487, train acc 0.112, test_acc 0.1, time 17.9 sec
# Epoch 81, loss 2.24869, train acc 0.112, test_acc 0.1, time 17.7 sec
# Epoch 82, loss 2.24836, train acc 0.112, test_acc 0.1, time 17.1 sec
# Epoch 83, loss 2.24833, train acc 0.109, test_acc 0.1, time 17.2 sec
# Epoch 84, loss 2.24816, train acc 0.112, test_acc 0.1, time 16.7 sec
# Epoch 85, loss 2.24831, train acc 0.1, test_acc 0.1, time 17.0 sec
# Epoch 86, loss 2.24851, train acc 0.11, test_acc 0.1, time 17.6 sec
# Epoch 87, loss 2.24837, train acc 0.106, test_acc 0.1, time 17.8 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 88, loss 0.303096, train acc 1, test_acc 0.1, time 63.0 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 89, loss 2.47672, train acc 0.112, test_acc 0.1, time 16.5 sec
# Epoch 90, loss 2.25321, train acc 0.112, test_acc 0.1, time 17.2 sec
# Epoch 91, loss 2.24875, train acc 0.112, test_acc 0.1, time 16.7 sec
# Epoch 92, loss 2.24825, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 93, loss 2.24833, train acc 0.108, test_acc 0.1, time 16.3 sec
# Epoch 94, loss 2.24855, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 95, loss 2.24835, train acc 0.101, test_acc 0.1, time 16.3 sec
# Epoch 96, loss 2.24852, train acc 0.112, test_acc 0.1, time 16.3 sec
# Epoch 97, loss 2.24834, train acc 0.105, test_acc 0.1, time 16.3 sec
# Epoch 98, loss 2.2481, train acc 0.101, test_acc 0.1, time 16.3 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 99, loss 0.303098, train acc 1, test_acc 0.1, time 57.7 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 100, loss 2.48919, train acc 0.112, test_acc 0.1, time 16.3 sec
# Epoch 101, loss 2.25358, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 102, loss 2.24848, train acc 0.112, test_acc 0.1, time 16.3 sec
# Epoch 103, loss 2.24841, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 104, loss 2.24836, train acc 0.112, test_acc 0.1, time 16.3 sec
# Epoch 105, loss 2.24852, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 106, loss 2.2487, train acc 0.104, test_acc 0.1, time 16.3 sec
# Epoch 107, loss 2.24832, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 108, loss 2.24827, train acc 0.113, test_acc 0.1, time 16.3 sec
# Epoch 109, loss 2.24827, train acc 0.112, test_acc 0.1, time 16.5 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 110, loss 0.302956, train acc 1, test_acc 0.1, time 64.6 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 111, loss 2.48305, train acc 0.112, test_acc 0.1, time 17.5 sec
# Epoch 112, loss 2.25396, train acc 0.112, test_acc 0.1, time 16.5 sec
# Epoch 113, loss 2.24876, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 114, loss 2.24816, train acc 0.112, test_acc 0.1, time 16.3 sec
# Epoch 115, loss 2.24826, train acc 0.112, test_acc 0.1, time 16.9 sec
# Epoch 116, loss 2.24846, train acc 0.109, test_acc 0.1, time 18.0 sec
# Epoch 117, loss 2.24838, train acc 0.108, test_acc 0.1, time 17.1 sec
# Epoch 118, loss 2.24848, train acc 0.098, test_acc 0.1, time 16.4 sec
# Epoch 119, loss 2.24835, train acc 0.112, test_acc 0.1, time 16.6 sec
# Epoch 120, loss 2.24844, train acc 0.103, test_acc 0.1, time 16.4 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 121, loss 0.302438, train acc 1, test_acc 0.1, time 58.2 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 122, loss 2.47506, train acc 0.112, test_acc 0.1, time 16.7 sec
# Epoch 123, loss 2.25355, train acc 0.112, test_acc 0.1, time 16.5 sec
# Epoch 124, loss 2.24906, train acc 0.112, test_acc 0.1, time 18.0 sec
# Epoch 125, loss 2.24858, train acc 0.112, test_acc 0.1, time 18.1 sec
# Epoch 126, loss 2.24838, train acc 0.112, test_acc 0.1, time 18.3 sec
# Epoch 127, loss 2.24808, train acc 0.112, test_acc 0.1, time 17.5 sec
# Epoch 128, loss 2.24844, train acc 0.11, test_acc 0.1, time 17.3 sec
# Epoch 129, loss 2.24845, train acc 0.112, test_acc 0.1, time 16.8 sec
# Epoch 130, loss 2.24858, train acc 0.105, test_acc 0.1, time 17.4 sec
# Epoch 131, loss 2.24822, train acc 0.104, test_acc 0.1, time 18.3 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 132, loss 0.302866, train acc 1, test_acc 0.1, time 59.0 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 133, loss 2.4888, train acc 0.112, test_acc 0.1, time 17.6 sec
# Epoch 134, loss 2.25422, train acc 0.112, test_acc 0.1, time 17.7 sec
# Epoch 135, loss 2.24841, train acc 0.112, test_acc 0.1, time 17.5 sec
# Epoch 136, loss 2.24841, train acc 0.112, test_acc 0.1, time 19.5 sec
# Epoch 137, loss 2.24833, train acc 0.112, test_acc 0.1, time 17.5 sec
# Epoch 138, loss 2.24841, train acc 0.092, test_acc 0.1, time 20.3 sec
# Epoch 139, loss 2.24846, train acc 0.112, test_acc 0.1, time 17.4 sec
# Epoch 140, loss 2.24831, train acc 0.112, test_acc 0.1, time 17.7 sec
# Epoch 141, loss 2.24834, train acc 0.103, test_acc 0.1, time 18.0 sec
# Epoch 142, loss 2.24832, train acc 0.096, test_acc 0.1, time 17.4 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 143, loss 0.303406, train acc 1, test_acc 0.1, time 59.0 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 144, loss 2.48396, train acc 0.112, test_acc 0.1, time 17.5 sec
# Epoch 145, loss 2.25392, train acc 0.112, test_acc 0.1, time 17.3 sec
# Epoch 146, loss 2.24855, train acc 0.112, test_acc 0.1, time 17.2 sec
# Epoch 147, loss 2.24819, train acc 0.112, test_acc 0.1, time 16.8 sec
# Epoch 148, loss 2.24828, train acc 0.112, test_acc 0.1, time 16.9 sec
# Epoch 149, loss 2.24849, train acc 0.109, test_acc 0.1, time 16.6 sec
# Epoch 150, loss 2.24838, train acc 0.105, test_acc 0.1, time 17.4 sec
# Epoch 151, loss 2.24822, train acc 0.106, test_acc 0.1, time 16.5 sec
# Epoch 152, loss 2.24815, train acc 0.108, test_acc 0.1, time 16.6 sec
# Epoch 153, loss 2.24868, train acc 0.112, test_acc 0.1, time 16.7 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 154, loss 0.302818, train acc 1, test_acc 0.1, time 58.1 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 155, loss 2.48979, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 156, loss 2.25467, train acc 0.112, test_acc 0.1, time 16.4 sec
# Epoch 157, loss 2.24903, train acc 0.112, test_acc 0.1, time 17.3 sec
# Epoch 158, loss 2.24858, train acc 0.112, test_acc 0.1, time 17.8 sec
# Epoch 159, loss 2.24833, train acc 0.112, test_acc 0.1, time 16.9 sec
# Epoch 160, loss 2.24835, train acc 0.112, test_acc 0.1, time 16.7 sec
# Epoch 161, loss 2.24853, train acc 0.101, test_acc 0.1, time 17.1 sec
# Epoch 162, loss 2.24824, train acc 0.103, test_acc 0.1, time 16.7 sec
# Epoch 163, loss 2.24861, train acc 0.11, test_acc 0.1, time 17.1 sec
# Epoch 164, loss 2.24853, train acc 0.112, test_acc 0.1, time 16.7 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 165, loss 0.302945, train acc 1, test_acc 0.1, time 62.0 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 166, loss 2.47702, train acc 0.112, test_acc 0.1, time 17.3 sec
# Epoch 167, loss 2.25398, train acc 0.112, test_acc 0.1, time 17.9 sec
# Epoch 168, loss 2.24888, train acc 0.112, test_acc 0.1, time 16.5 sec
# Epoch 169, loss 2.2487, train acc 0.112, test_acc 0.1, time 21.8 sec
# Epoch 170, loss 2.24848, train acc 0.11, test_acc 0.1, time 19.4 sec
# Epoch 171, loss 2.24818, train acc 0.112, test_acc 0.1, time 17.8 sec
# Epoch 172, loss 2.24839, train acc 0.108, test_acc 0.1, time 17.6 sec
# Epoch 173, loss 2.24869, train acc 0.112, test_acc 0.1, time 16.8 sec
# Epoch 174, loss 2.24843, train acc 0.109, test_acc 0.1, time 16.6 sec
# Epoch 175, loss 2.24851, train acc 0.109, test_acc 0.1, time 17.4 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 176, loss 0.303293, train acc 1, test_acc 0.1, time 65.0 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 177, loss 2.47656, train acc 0.112, test_acc 0.1, time 17.4 sec
# Epoch 178, loss 2.2543, train acc 0.112, test_acc 0.1, time 17.2 sec
# Epoch 179, loss 2.24862, train acc 0.112, test_acc 0.1, time 17.3 sec
# Epoch 180, loss 2.24793, train acc 0.112, test_acc 0.1, time 17.5 sec
# Epoch 181, loss 2.24824, train acc 0.105, test_acc 0.1, time 17.7 sec
# Epoch 182, loss 2.2483, train acc 0.109, test_acc 0.1, time 17.6 sec
# Epoch 183, loss 2.2485, train acc 0.101, test_acc 0.1, time 17.1 sec
# Epoch 184, loss 2.24826, train acc 0.101, test_acc 0.1, time 17.3 sec
# Epoch 185, loss 2.24832, train acc 0.106, test_acc 0.1, time 18.0 sec
# Epoch 186, loss 2.24837, train acc 0.108, test_acc 0.1, time 17.3 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# agent_SSL:  0.0973
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# 微调带有代理标签数据
# Epoch 187, loss 0.302983, train acc 1, test_acc 0.1, time 61.4 sec
# 分类指标：
#              precision    recall  f1-score   support
#
#           0       0.10      1.00      0.18       973
#           1       0.00      0.00      0.00       979
#           2       0.00      0.00      0.00      1030
#           3       0.00      0.00      0.00      1023
#           4       0.00      0.00      0.00       933
#           5       0.00      0.00      0.00      1015
#           6       0.00      0.00      0.00       996
#           7       0.00      0.00      0.00       994
#           8       0.00      0.00      0.00      1017
#           9       0.00      0.00      0.00      1040
#
# avg / total       0.01      0.10      0.02     10000
#
# 微调有标签数据
# ~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~~_~
# Epoch 188, loss 2.48027, train acc 0.112, test_acc 0.1, time 17.4 sec
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e07768b7daa6> in <module>()
#       9     sw.add_scalar('accuracy_curves',
#      10                   {unlabelset.name + '_SSL': dataset.agency_acc}, epoch)
# ---> 11     net = model.train(net, dataset.train, testset, epochs=10, start=epoch)
#      12     dataset.agent(net)
#      13     print(unlabelset.name + '_SSL: ', dataset.agency_acc)
#
# E:/zlab\xtrain.py in train(self, net, trainset, testset, epochs, start)
#      98                 sw.add_graph(net)
#      99             train_acc = train_acc_sum / m
# --> 100             test_acc = self.evaluate_accuracy(net, testset)
#     101             print('Epoch %d, loss %g, train acc %g, test_acc %g, time %.1f sec' %
#     102                   (epoch, train_l_sum / n, train_acc,
#
# E:/zlab\xtrain.py in evaluate_accuracy(self, net, testset)
#      63                 cpu()) == ys).sum()
#      64             n += ys.size
# ---> 65         return acc.asscalar() / n
#      66
#      67     def train(self, net, trainset, testset, epochs, start=0):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mxnet\ndarray\ndarray.py in asscalar(self)
#    1988         if self.shape != (1,):
#    1989             raise ValueError("The current array is not a scalar")
# -> 1990         return self.asnumpy()[0]
#    1991
#    1992     def astype(self, dtype, copy=True):
#
# C:\ProgramData\Anaconda3\lib\site-packages\mxnet\ndarray\ndarray.py in asnumpy(self)
#    1970             self.handle,
#    1971             data.ctypes.data_as(ctypes.c_void_p),
# -> 1972             ctypes.c_size_t(data.size)))
#    1973         return data
#    1974
#
# KeyboardInterrupt:
