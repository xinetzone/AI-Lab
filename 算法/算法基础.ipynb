# %% [markdown]
# # 链表 (linked list)
#
# **链表** (linked list): 通常是由一系列节点来实现的, 其每个节点（尾节点除外）中都持有一个指向下一节点的引用。

# %%
class Node:
    '''
    链表 (linked list):
    '''
    def __init__(self, value, next_node=None):
        self.value = value
        self.next = next_node

# %%
L = Node('a', Node('b', Node('c', Node('d'))))

# %%
L.value
# Out:
# 'a'

# %%
L.next.next.value
# Out:
# 'c'

# %% [markdown]
# # Bunch 模式

# %%
class Tree:
    '''
    二叉树
    '''
    def __init__(self, left, right):
        self.left = left
        self.right = right

# %%
t = Tree(Tree('a', 'b'), Tree('c', 'd'))

# %%
t.left.right
# Out:
# 'b'

# %%
class Tree:
    '''
    multiway tree (多路搜索树)
    '''
    def __init__(self, kids, next_node=None):
        self.kids = self.val = kids
        self.next = next_node

# %%
t = Tree(Tree('a', Tree('b', Tree('c', Tree('d')))))

# %%
t.kids.next.next.val
# Out:
# 'c'

# %%
class Bunch(dict):
    '''
    Bunch 设计模式
    '''
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.__dict__ = self

# %% [markdown]
# ## 命令行的形式创建

# %%
x = Bunch(name='Zhang Yu', position='Public Relations')

# %%
x.name
# Out:
# 'Zhang Yu'

# %% [markdown]
# ## 遍历

# %%
T = Bunch

t = T(left=T(left='a', right='b'), right=T(left='c'))

# %%
t.left
# Out:
# {'left': 'a', 'right': 'b'}

# %%
t.left.right
# Out:
# 'b'

# %%
t['left']['right']
# Out:
# 'b'

# %%
'left' in t.right
# Out:
# True

# %% [markdown]
# # 计数初步

# %%
 from random import randrange

# %%
n = 10**90
p = randrange(n)

# %%
p
# Out:
# 82304690845422810700840969530464832648295766882795342851390637081113073433378167814212052

# %% [markdown]
# ## 递归

# %%
def S(seq, i=0):
    '''
    求和公式
    '''
    assert i <= len(seq)
    if i == len(seq): return 0
    return S(seq, i+1) + seq[i]

seq = [1, 2, 3]
S(seq, 0)
# Out:
# 6

# %% [markdown]
# 为了更加容易理解递归函数, 改写为：

# %%
def S(seq, i=0):
    '''
    求和公式
    '''
    assert i <= len(seq)
    if i == len(seq):
        reg = 0
    else:
        reg = S(seq, i+1) + seq[i]
    print('seq[%i]: S[%i]=' % (i, i), reg)
    return reg


seq = [1, 2, 3]
S(seq, 0)
# Out:
# seq[3]: S[3]= 0
# seq[2]: S[2]= 3
# seq[1]: S[1]= 5
# seq[0]: S[0]= 6
# 6

# %%
def fact(n):
    print("factorial has been called with n = " + str(n))
    if n == 1:
        return 1
    else:
        res = n * fact(n - 1)
        print("intermediate result for ", n, " * fact(", n - 1, "): ", res)
        return res


print(fact(10))
# Out:
# factorial has been called with n = 10
# factorial has been called with n = 9
# factorial has been called with n = 8
# factorial has been called with n = 7
# factorial has been called with n = 6
# factorial has been called with n = 5
# factorial has been called with n = 4
# factorial has been called with n = 3
# factorial has been called with n = 2
# factorial has been called with n = 1
# intermediate result for  2  * fact( 1 ):  2
# intermediate result for  3  * fact( 2 ):  6
# intermediate result for  4  * fact( 3 ):  24
# intermediate result for  5  * fact( 4 ):  120
# intermediate result for  6  * fact( 5 ):  720
# intermediate result for  7  * fact( 6 ):  5040
# intermediate result for  8  * fact( 7 ):  40320
# intermediate result for  9  * fact( 8 ):  362880
# intermediate result for  10  * fact( 9 ):  3628800
# 3628800

# %% [markdown]
# 从上面的结果可以看出：递归的实现是以堆栈的形式来操作的，因而，使用递归函数需要注意防止栈溢出。在计算机中，函数调用是通过栈（stack）这种数据结构实现的，每当进入一个函数调用，栈就会加一层栈帧，每当函数返回，栈就会减一层栈帧。由于栈的大小不是无限的，所以，递归调用的次数过多，会导致栈溢出。可以试试 `fact(1000)`：

# %%
fact(1000000000000000000000000000000000000000)
# Out:
# factorial has been called with n = 1000000000000000000000000000000000000000
# factorial has been called with n = 999999999999999999999999999999999999999
# factorial has been called with n = 999999999999999999999999999999999999998
# factorial has been called with n = 999999999999999999999999999999999999997
# factorial has been called with n = 999999999999999999999999999999999999996
# factorial has been called with n = 999999999999999999999999999999999999995
# factorial has been called with n = 999999999999999999999999999999999999994
# factorial has been called with n = 999999999999999999999999999999999999993
# factorial has been called with n = 999999999999999999999999999999999999992
# factorial has been called with n = 999999999999999999999999999999999999991
# factorial has been called with n = 999999999999999999999999999999999999990
# factorial has been called with n = 999999999999999999999999999999999999989
# factorial has been called with n = 999999999999999999999999999999999999988
# factorial has been called with n = 999999999999999999999999999999999999987
# factorial has been called with n = 999999999999999999999999999999999999986
# factorial has been called with n = 999999999999999999999999999999999999985
# factorial has been called with n = 999999999999999999999999999999999999984
# factorial has been called with n = 999999999999999999999999999999999999983
# factorial has been called with n = 999999999999999999999999999999999999982
# factorial has been called with n = 999999999999999999999999999999999999981
# factorial has been called with n = 999999999999999999999999999999999999980
# factorial has been called with n = 999999999999999999999999999999999999979
# factorial has been called with n = 999999999999999999999999999999999999978
# factorial has been called with n = 999999999999999999999999999999999999977
# factorial has been called with n = 999999999999999999999999999999999999976
# factorial has been called with n = 999999999999999999999999999999999999975
# factorial has been called with n = 999999999999999999999999999999999999974
# factorial has been called with n = 999999999999999999999999999999999999973
# factorial has been called with n = 999999999999999999999999999999999999972
# factorial has been called with n = 999999999999999999999999999999999999971
# factorial has been called with n = 999999999999999999999999999999999999970
# factorial has been called with n = 999999999999999999999999999999999999969
# factorial has been called with n = 999999999999999999999999999999999999968
# factorial has been called with n = 999999999999999999999999999999999999967
# factorial has been called with n = 999999999999999999999999999999999999966
# factorial has been called with n = 999999999999999999999999999999999999965
# factorial has been called with n = 999999999999999999999999999999999999964
# factorial has been called with n = 999999999999999999999999999999999999963
# factorial has been called with n = 999999999999999999999999999999999999962
# factorial has been called with n = 999999999999999999999999999999999999961
# factorial has been called with n = 999999999999999999999999999999999999960
# factorial has been called with n = 999999999999999999999999999999999999959
# factorial has been called with n = 999999999999999999999999999999999999958
# factorial has been called with n = 999999999999999999999999999999999999957
# factorial has been called with n = 999999999999999999999999999999999999956
# factorial has been called with n = 999999999999999999999999999999999999955
# factorial has been called with n = 999999999999999999999999999999999999954
# factorial has been called with n = 999999999999999999999999999999999999953
# factorial has been called with n = 999999999999999999999999999999999999952
# factorial has been called with n = 999999999999999999999999999999999999951
# factorial has been called with n = 999999999999999999999999999999999999950
# factorial has been called with n = 999999999999999999999999999999999999949
# factorial has been called with n = 999999999999999999999999999999999999948
# factorial has been called with n = 999999999999999999999999999999999999947
# factorial has been called with n = 999999999999999999999999999999999999946
# factorial has been called with n = 999999999999999999999999999999999999945
# factorial has been called with n = 999999999999999999999999999999999999944
# factorial has been called with n = 999999999999999999999999999999999999943
# factorial has been called with n = 999999999999999999999999999999999999942
# factorial has been called with n = 999999999999999999999999999999999999941
# factorial has been called with n = 999999999999999999999999999999999999940
# factorial has been called with n = 999999999999999999999999999999999999939
# factorial has been called with n = 999999999999999999999999999999999999938
# factorial has been called with n = 999999999999999999999999999999999999937
# factorial has been called with n = 999999999999999999999999999999999999936
# factorial has been called with n = 999999999999999999999999999999999999935
# factorial has been called with n = 999999999999999999999999999999999999934
# factorial has been called with n = 999999999999999999999999999999999999933
# factorial has been called with n = 999999999999999999999999999999999999932
# factorial has been called with n = 999999999999999999999999999999999999931
# factorial has been called with n = 999999999999999999999999999999999999930
# factorial has been called with n = 999999999999999999999999999999999999929
# factorial has been called with n = 999999999999999999999999999999999999928
# factorial has been called with n = 999999999999999999999999999999999999927
# factorial has been called with n = 999999999999999999999999999999999999926
# factorial has been called with n = 999999999999999999999999999999999999925
# factorial has been called with n = 999999999999999999999999999999999999924
# factorial has been called with n = 999999999999999999999999999999999999923
# factorial has been called with n = 999999999999999999999999999999999999922
# factorial has been called with n = 999999999999999999999999999999999999921
# factorial has been called with n = 999999999999999999999999999999999999920
# factorial has been called with n = 999999999999999999999999999999999999919
# factorial has been called with n = 999999999999999999999999999999999999918
# factorial has been called with n = 999999999999999999999999999999999999917
# factorial has been called with n = 999999999999999999999999999999999999916
# factorial has been called with n = 999999999999999999999999999999999999915
# factorial has been called with n = 999999999999999999999999999999999999914
# factorial has been called with n = 999999999999999999999999999999999999913
# factorial has been called with n = 999999999999999999999999999999999999912
# factorial has been called with n = 999999999999999999999999999999999999911
# factorial has been called with n = 999999999999999999999999999999999999910
# factorial has been called with n = 999999999999999999999999999999999999909
# factorial has been called with n = 999999999999999999999999999999999999908
# factorial has been called with n = 999999999999999999999999999999999999907
# factorial has been called with n = 999999999999999999999999999999999999906
# factorial has been called with n = 999999999999999999999999999999999999905
# factorial has been called with n = 999999999999999999999999999999999999904
# factorial has been called with n = 999999999999999999999999999999999999903
# factorial has been called with n = 999999999999999999999999999999999999902
# factorial has been called with n = 999999999999999999999999999999999999901
# factorial has been called with n = 999999999999999999999999999999999999900
# factorial has been called with n = 999999999999999999999999999999999999899
# factorial has been called with n = 999999999999999999999999999999999999898
# factorial has been called with n = 999999999999999999999999999999999999897
# factorial has been called with n = 999999999999999999999999999999999999896
# factorial has been called with n = 999999999999999999999999999999999999895
# factorial has been called with n = 999999999999999999999999999999999999894
# factorial has been called with n = 999999999999999999999999999999999999893
# factorial has been called with n = 999999999999999999999999999999999999892
# factorial has been called with n = 999999999999999999999999999999999999891
# factorial has been called with n = 999999999999999999999999999999999999890
# factorial has been called with n = 999999999999999999999999999999999999889
# factorial has been called with n = 999999999999999999999999999999999999888
# factorial has been called with n = 999999999999999999999999999999999999887
# factorial has been called with n = 999999999999999999999999999999999999886
# factorial has been called with n = 999999999999999999999999999999999999885
# factorial has been called with n = 999999999999999999999999999999999999884
# factorial has been called with n = 999999999999999999999999999999999999883
# factorial has been called with n = 999999999999999999999999999999999999882
# factorial has been called with n = 999999999999999999999999999999999999881
# factorial has been called with n = 999999999999999999999999999999999999880
# factorial has been called with n = 999999999999999999999999999999999999879
# factorial has been called with n = 999999999999999999999999999999999999878
# factorial has been called with n = 999999999999999999999999999999999999877
# factorial has been called with n = 999999999999999999999999999999999999876
# factorial has been called with n = 999999999999999999999999999999999999875
# factorial has been called with n = 999999999999999999999999999999999999874
# factorial has been called with n = 999999999999999999999999999999999999873
# factorial has been called with n = 999999999999999999999999999999999999872
# factorial has been called with n = 999999999999999999999999999999999999871
# factorial has been called with n = 999999999999999999999999999999999999870
# factorial has been called with n = 999999999999999999999999999999999999869
# factorial has been called with n = 999999999999999999999999999999999999868
# factorial has been called with n = 999999999999999999999999999999999999867
# factorial has been called with n = 999999999999999999999999999999999999866
# factorial has been called with n = 999999999999999999999999999999999999865
# factorial has been called with n = 999999999999999999999999999999999999864
# factorial has been called with n = 999999999999999999999999999999999999863
# factorial has been called with n = 999999999999999999999999999999999999862
# factorial has been called with n = 999999999999999999999999999999999999861
# factorial has been called with n = 999999999999999999999999999999999999860
# factorial has been called with n = 999999999999999999999999999999999999859
# factorial has been called with n = 999999999999999999999999999999999999858
# factorial has been called with n = 999999999999999999999999999999999999857
# factorial has been called with n = 999999999999999999999999999999999999856
# factorial has been called with n = 999999999999999999999999999999999999855
# factorial has been called with n = 999999999999999999999999999999999999854
# factorial has been called with n = 999999999999999999999999999999999999853
# factorial has been called with n = 999999999999999999999999999999999999852
# factorial has been called with n = 999999999999999999999999999999999999851
# factorial has been called with n = 999999999999999999999999999999999999850
# factorial has been called with n = 999999999999999999999999999999999999849
# factorial has been called with n = 999999999999999999999999999999999999848
# factorial has been called with n = 999999999999999999999999999999999999847
# factorial has been called with n = 999999999999999999999999999999999999846
# factorial has been called with n = 999999999999999999999999999999999999845
# factorial has been called with n = 999999999999999999999999999999999999844
# factorial has been called with n = 999999999999999999999999999999999999843
# factorial has been called with n = 999999999999999999999999999999999999842
# factorial has been called with n = 999999999999999999999999999999999999841
# factorial has been called with n = 999999999999999999999999999999999999840
# factorial has been called with n = 999999999999999999999999999999999999839
# factorial has been called with n = 999999999999999999999999999999999999838
# factorial has been called with n = 999999999999999999999999999999999999837
# factorial has been called with n = 999999999999999999999999999999999999836
# factorial has been called with n = 999999999999999999999999999999999999835
# factorial has been called with n = 999999999999999999999999999999999999834
# factorial has been called with n = 999999999999999999999999999999999999833
# factorial has been called with n = 999999999999999999999999999999999999832
# factorial has been called with n = 999999999999999999999999999999999999831
# factorial has been called with n = 999999999999999999999999999999999999830
# factorial has been called with n = 999999999999999999999999999999999999829
# factorial has been called with n = 999999999999999999999999999999999999828
# factorial has been called with n = 999999999999999999999999999999999999827
# factorial has been called with n = 999999999999999999999999999999999999826
# factorial has been called with n = 999999999999999999999999999999999999825
# factorial has been called with n = 999999999999999999999999999999999999824
# factorial has been called with n = 999999999999999999999999999999999999823
# factorial has been called with n = 999999999999999999999999999999999999822
# factorial has been called with n = 999999999999999999999999999999999999821
# factorial has been called with n = 999999999999999999999999999999999999820
# factorial has been called with n = 999999999999999999999999999999999999819
# factorial has been called with n = 999999999999999999999999999999999999818
# factorial has been called with n = 999999999999999999999999999999999999817
# factorial has been called with n = 999999999999999999999999999999999999816
# factorial has been called with n = 999999999999999999999999999999999999815
# factorial has been called with n = 999999999999999999999999999999999999814
# factorial has been called with n = 999999999999999999999999999999999999813
# factorial has been called with n = 999999999999999999999999999999999999812
# factorial has been called with n = 999999999999999999999999999999999999811
# factorial has been called with n = 999999999999999999999999999999999999810
# factorial has been called with n = 999999999999999999999999999999999999809
# factorial has been called with n = 999999999999999999999999999999999999808
# factorial has been called with n = 999999999999999999999999999999999999807
# factorial has been called with n = 999999999999999999999999999999999999806
# factorial has been called with n = 999999999999999999999999999999999999805
# factorial has been called with n = 999999999999999999999999999999999999804
# factorial has been called with n = 999999999999999999999999999999999999803
# factorial has been called with n = 999999999999999999999999999999999999802
# factorial has been called with n = 999999999999999999999999999999999999801
# factorial has been called with n = 999999999999999999999999999999999999800
# factorial has been called with n = 999999999999999999999999999999999999799
# factorial has been called with n = 999999999999999999999999999999999999798
# factorial has been called with n = 999999999999999999999999999999999999797
# factorial has been called with n = 999999999999999999999999999999999999796
# factorial has been called with n = 999999999999999999999999999999999999795
# factorial has been called with n = 999999999999999999999999999999999999794
# factorial has been called with n = 999999999999999999999999999999999999793
# factorial has been called with n = 999999999999999999999999999999999999792
# factorial has been called with n = 999999999999999999999999999999999999791
# factorial has been called with n = 999999999999999999999999999999999999790
# factorial has been called with n = 999999999999999999999999999999999999789
# factorial has been called with n = 999999999999999999999999999999999999788
# factorial has been called with n = 999999999999999999999999999999999999787
# factorial has been called with n = 999999999999999999999999999999999999786
# factorial has been called with n = 999999999999999999999999999999999999785
# factorial has been called with n = 999999999999999999999999999999999999784
# factorial has been called with n = 999999999999999999999999999999999999783
# factorial has been called with n = 999999999999999999999999999999999999782
# factorial has been called with n = 999999999999999999999999999999999999781
# factorial has been called with n = 999999999999999999999999999999999999780
# factorial has been called with n = 999999999999999999999999999999999999779
# factorial has been called with n = 999999999999999999999999999999999999778
# factorial has been called with n = 999999999999999999999999999999999999777
# factorial has been called with n = 999999999999999999999999999999999999776
# factorial has been called with n = 999999999999999999999999999999999999775
# factorial has been called with n = 999999999999999999999999999999999999774
# factorial has been called with n = 999999999999999999999999999999999999773
# factorial has been called with n = 999999999999999999999999999999999999772
# factorial has been called with n = 999999999999999999999999999999999999771
# factorial has been called with n = 999999999999999999999999999999999999770
# factorial has been called with n = 999999999999999999999999999999999999769
# factorial has been called with n = 999999999999999999999999999999999999768
# factorial has been called with n = 999999999999999999999999999999999999767
# factorial has been called with n = 999999999999999999999999999999999999766
# factorial has been called with n = 999999999999999999999999999999999999765
# factorial has been called with n = 999999999999999999999999999999999999764
# factorial has been called with n = 999999999999999999999999999999999999763
# factorial has been called with n = 999999999999999999999999999999999999762
# factorial has been called with n = 999999999999999999999999999999999999761
# factorial has been called with n = 999999999999999999999999999999999999760
# factorial has been called with n = 999999999999999999999999999999999999759
# factorial has been called with n = 999999999999999999999999999999999999758
# factorial has been called with n = 999999999999999999999999999999999999757
# factorial has been called with n = 999999999999999999999999999999999999756
# factorial has been called with n = 999999999999999999999999999999999999755
# factorial has been called with n = 999999999999999999999999999999999999754
# factorial has been called with n = 999999999999999999999999999999999999753
# factorial has been called with n = 999999999999999999999999999999999999752
# factorial has been called with n = 999999999999999999999999999999999999751
# factorial has been called with n = 999999999999999999999999999999999999750
# factorial has been called with n = 999999999999999999999999999999999999749
# factorial has been called with n = 999999999999999999999999999999999999748
# factorial has been called with n = 999999999999999999999999999999999999747
# factorial has been called with n = 999999999999999999999999999999999999746
# factorial has been called with n = 999999999999999999999999999999999999745
# factorial has been called with n = 999999999999999999999999999999999999744
# factorial has been called with n = 999999999999999999999999999999999999743
# factorial has been called with n = 999999999999999999999999999999999999742
# factorial has been called with n = 999999999999999999999999999999999999741
# factorial has been called with n = 999999999999999999999999999999999999740
# factorial has been called with n = 999999999999999999999999999999999999739
# factorial has been called with n = 999999999999999999999999999999999999738
# factorial has been called with n = 999999999999999999999999999999999999737
# factorial has been called with n = 999999999999999999999999999999999999736
# factorial has been called with n = 999999999999999999999999999999999999735
# factorial has been called with n = 999999999999999999999999999999999999734
# factorial has been called with n = 999999999999999999999999999999999999733
# factorial has been called with n = 999999999999999999999999999999999999732
# factorial has been called with n = 999999999999999999999999999999999999731
# factorial has been called with n = 999999999999999999999999999999999999730
# factorial has been called with n = 999999999999999999999999999999999999729
# factorial has been called with n = 999999999999999999999999999999999999728
# factorial has been called with n = 999999999999999999999999999999999999727
# factorial has been called with n = 999999999999999999999999999999999999726
# factorial has been called with n = 999999999999999999999999999999999999725
# factorial has been called with n = 999999999999999999999999999999999999724
# factorial has been called with n = 999999999999999999999999999999999999723
# factorial has been called with n = 999999999999999999999999999999999999722
# factorial has been called with n = 999999999999999999999999999999999999721
# factorial has been called with n = 999999999999999999999999999999999999720
# factorial has been called with n = 999999999999999999999999999999999999719
# factorial has been called with n = 999999999999999999999999999999999999718
# factorial has been called with n = 999999999999999999999999999999999999717
# factorial has been called with n = 999999999999999999999999999999999999716
# factorial has been called with n = 999999999999999999999999999999999999715
# factorial has been called with n = 999999999999999999999999999999999999714
# factorial has been called with n = 999999999999999999999999999999999999713
# factorial has been called with n = 999999999999999999999999999999999999712
# factorial has been called with n = 999999999999999999999999999999999999711
# factorial has been called with n = 999999999999999999999999999999999999710
# factorial has been called with n = 999999999999999999999999999999999999709
# factorial has been called with n = 999999999999999999999999999999999999708
# factorial has been called with n = 999999999999999999999999999999999999707
# factorial has been called with n = 999999999999999999999999999999999999706
# factorial has been called with n = 999999999999999999999999999999999999705
# factorial has been called with n = 999999999999999999999999999999999999704
# factorial has been called with n = 999999999999999999999999999999999999703
# factorial has been called with n = 999999999999999999999999999999999999702
# factorial has been called with n = 999999999999999999999999999999999999701
# factorial has been called with n = 999999999999999999999999999999999999700
# factorial has been called with n = 999999999999999999999999999999999999699
# factorial has been called with n = 999999999999999999999999999999999999698
# factorial has been called with n = 999999999999999999999999999999999999697
# factorial has been called with n = 999999999999999999999999999999999999696
# factorial has been called with n = 999999999999999999999999999999999999695
# factorial has been called with n = 999999999999999999999999999999999999694
# factorial has been called with n = 999999999999999999999999999999999999693
# factorial has been called with n = 999999999999999999999999999999999999692
# factorial has been called with n = 999999999999999999999999999999999999691
# factorial has been called with n = 999999999999999999999999999999999999690
# factorial has been called with n = 999999999999999999999999999999999999689
# factorial has been called with n = 999999999999999999999999999999999999688
# factorial has been called with n = 999999999999999999999999999999999999687
# factorial has been called with n = 999999999999999999999999999999999999686
# factorial has been called with n = 999999999999999999999999999999999999685
# factorial has been called with n = 999999999999999999999999999999999999684
# factorial has been called with n = 999999999999999999999999999999999999683
# factorial has been called with n = 999999999999999999999999999999999999682
# factorial has been called with n = 999999999999999999999999999999999999681
# factorial has been called with n = 999999999999999999999999999999999999680
# factorial has been called with n = 999999999999999999999999999999999999679
# factorial has been called with n = 999999999999999999999999999999999999678
# factorial has been called with n = 999999999999999999999999999999999999677
# factorial has been called with n = 999999999999999999999999999999999999676
# factorial has been called with n = 999999999999999999999999999999999999675
# factorial has been called with n = 999999999999999999999999999999999999674
# factorial has been called with n = 999999999999999999999999999999999999673
# factorial has been called with n = 999999999999999999999999999999999999672
# factorial has been called with n = 999999999999999999999999999999999999671
# factorial has been called with n = 999999999999999999999999999999999999670
# factorial has been called with n = 999999999999999999999999999999999999669
# factorial has been called with n = 999999999999999999999999999999999999668
# factorial has been called with n = 999999999999999999999999999999999999667
# factorial has been called with n = 999999999999999999999999999999999999666
# factorial has been called with n = 999999999999999999999999999999999999665
# factorial has been called with n = 999999999999999999999999999999999999664
# factorial has been called with n = 999999999999999999999999999999999999663
# factorial has been called with n = 999999999999999999999999999999999999662
# factorial has been called with n = 999999999999999999999999999999999999661
# factorial has been called with n = 999999999999999999999999999999999999660
# factorial has been called with n = 999999999999999999999999999999999999659
# factorial has been called with n = 999999999999999999999999999999999999658
# factorial has been called with n = 999999999999999999999999999999999999657
# factorial has been called with n = 999999999999999999999999999999999999656
# factorial has been called with n = 999999999999999999999999999999999999655
# factorial has been called with n = 999999999999999999999999999999999999654
# factorial has been called with n = 999999999999999999999999999999999999653
# factorial has been called with n = 999999999999999999999999999999999999652
# factorial has been called with n = 999999999999999999999999999999999999651
# factorial has been called with n = 999999999999999999999999999999999999650
# factorial has been called with n = 999999999999999999999999999999999999649
# factorial has been called with n = 999999999999999999999999999999999999648
# factorial has been called with n = 999999999999999999999999999999999999647
# factorial has been called with n = 999999999999999999999999999999999999646
# factorial has been called with n = 999999999999999999999999999999999999645
# factorial has been called with n = 999999999999999999999999999999999999644
# factorial has been called with n = 999999999999999999999999999999999999643
# factorial has been called with n = 999999999999999999999999999999999999642
# factorial has been called with n = 999999999999999999999999999999999999641
# factorial has been called with n = 999999999999999999999999999999999999640
# factorial has been called with n = 999999999999999999999999999999999999639
# factorial has been called with n = 999999999999999999999999999999999999638
# factorial has been called with n = 999999999999999999999999999999999999637
# factorial has been called with n = 999999999999999999999999999999999999636
# factorial has been called with n = 999999999999999999999999999999999999635
# factorial has been called with n = 999999999999999999999999999999999999634
# factorial has been called with n = 999999999999999999999999999999999999633
# factorial has been called with n = 999999999999999999999999999999999999632
# factorial has been called with n = 999999999999999999999999999999999999631
# factorial has been called with n = 999999999999999999999999999999999999630
# factorial has been called with n = 999999999999999999999999999999999999629
# factorial has been called with n = 999999999999999999999999999999999999628
# factorial has been called with n = 999999999999999999999999999999999999627
# factorial has been called with n = 999999999999999999999999999999999999626
# factorial has been called with n = 999999999999999999999999999999999999625
# factorial has been called with n = 999999999999999999999999999999999999624
# factorial has been called with n = 999999999999999999999999999999999999623
# factorial has been called with n = 999999999999999999999999999999999999622
# factorial has been called with n = 999999999999999999999999999999999999621
# factorial has been called with n = 999999999999999999999999999999999999620
# factorial has been called with n = 999999999999999999999999999999999999619
# factorial has been called with n = 999999999999999999999999999999999999618
# factorial has been called with n = 999999999999999999999999999999999999617
# factorial has been called with n = 999999999999999999999999999999999999616
# factorial has been called with n = 999999999999999999999999999999999999615
# factorial has been called with n = 999999999999999999999999999999999999614
# factorial has been called with n = 999999999999999999999999999999999999613
# factorial has been called with n = 999999999999999999999999999999999999612
# factorial has been called with n = 999999999999999999999999999999999999611
# factorial has been called with n = 999999999999999999999999999999999999610
# factorial has been called with n = 999999999999999999999999999999999999609
# factorial has been called with n = 999999999999999999999999999999999999608
# factorial has been called with n = 999999999999999999999999999999999999607
# factorial has been called with n = 999999999999999999999999999999999999606
# factorial has been called with n = 999999999999999999999999999999999999605
# factorial has been called with n = 999999999999999999999999999999999999604
# factorial has been called with n = 999999999999999999999999999999999999603
# factorial has been called with n = 999999999999999999999999999999999999602
# factorial has been called with n = 999999999999999999999999999999999999601
# factorial has been called with n = 999999999999999999999999999999999999600
# factorial has been called with n = 999999999999999999999999999999999999599
# factorial has been called with n = 999999999999999999999999999999999999598
# factorial has been called with n = 999999999999999999999999999999999999597
# factorial has been called with n = 999999999999999999999999999999999999596
# factorial has been called with n = 999999999999999999999999999999999999595
# factorial has been called with n = 999999999999999999999999999999999999594
# factorial has been called with n = 999999999999999999999999999999999999593
# factorial has been called with n = 999999999999999999999999999999999999592
# factorial has been called with n = 999999999999999999999999999999999999591
# factorial has been called with n = 999999999999999999999999999999999999590
# factorial has been called with n = 999999999999999999999999999999999999589
# factorial has been called with n = 999999999999999999999999999999999999588
# factorial has been called with n = 999999999999999999999999999999999999587
# factorial has been called with n = 999999999999999999999999999999999999586
# factorial has been called with n = 999999999999999999999999999999999999585
# factorial has been called with n = 999999999999999999999999999999999999584
# factorial has been called with n = 999999999999999999999999999999999999583
# factorial has been called with n = 999999999999999999999999999999999999582
# factorial has been called with n = 999999999999999999999999999999999999581
# factorial has been called with n = 999999999999999999999999999999999999580
# factorial has been called with n = 999999999999999999999999999999999999579
# factorial has been called with n = 999999999999999999999999999999999999578
# factorial has been called with n = 999999999999999999999999999999999999577
# factorial has been called with n = 999999999999999999999999999999999999576
# factorial has been called with n = 999999999999999999999999999999999999575
# factorial has been called with n = 999999999999999999999999999999999999574
# factorial has been called with n = 999999999999999999999999999999999999573
# factorial has been called with n = 999999999999999999999999999999999999572
# factorial has been called with n = 999999999999999999999999999999999999571
# factorial has been called with n = 999999999999999999999999999999999999570
# factorial has been called with n = 999999999999999999999999999999999999569
# factorial has been called with n = 999999999999999999999999999999999999568
# factorial has been called with n = 999999999999999999999999999999999999567
# factorial has been called with n = 999999999999999999999999999999999999566
# factorial has been called with n = 999999999999999999999999999999999999565
# factorial has been called with n = 999999999999999999999999999999999999564
# factorial has been called with n = 999999999999999999999999999999999999563
# factorial has been called with n = 999999999999999999999999999999999999562
# factorial has been called with n = 999999999999999999999999999999999999561
# factorial has been called with n = 999999999999999999999999999999999999560
# factorial has been called with n = 999999999999999999999999999999999999559
# factorial has been called with n = 999999999999999999999999999999999999558
# factorial has been called with n = 999999999999999999999999999999999999557
# factorial has been called with n = 999999999999999999999999999999999999556
# factorial has been called with n = 999999999999999999999999999999999999555
# factorial has been called with n = 999999999999999999999999999999999999554
# factorial has been called with n = 999999999999999999999999999999999999553
# factorial has been called with n = 999999999999999999999999999999999999552
# factorial has been called with n = 999999999999999999999999999999999999551
# factorial has been called with n = 999999999999999999999999999999999999550
# factorial has been called with n = 999999999999999999999999999999999999549
# factorial has been called with n = 999999999999999999999999999999999999548
# factorial has been called with n = 999999999999999999999999999999999999547
# factorial has been called with n = 999999999999999999999999999999999999546
# factorial has been called with n = 999999999999999999999999999999999999545
# factorial has been called with n = 999999999999999999999999999999999999544
# factorial has been called with n = 999999999999999999999999999999999999543
# factorial has been called with n = 999999999999999999999999999999999999542
# factorial has been called with n = 999999999999999999999999999999999999541
# factorial has been called with n = 999999999999999999999999999999999999540
# factorial has been called with n = 999999999999999999999999999999999999539
# factorial has been called with n = 999999999999999999999999999999999999538
# factorial has been called with n = 999999999999999999999999999999999999537
# factorial has been called with n = 999999999999999999999999999999999999536
# factorial has been called with n = 999999999999999999999999999999999999535
# factorial has been called with n = 999999999999999999999999999999999999534
# factorial has been called with n = 999999999999999999999999999999999999533
# factorial has been called with n = 999999999999999999999999999999999999532
# factorial has been called with n = 999999999999999999999999999999999999531
# factorial has been called with n = 999999999999999999999999999999999999530
# factorial has been called with n = 999999999999999999999999999999999999529
# factorial has been called with n = 999999999999999999999999999999999999528
# factorial has been called with n = 999999999999999999999999999999999999527
# factorial has been called with n = 999999999999999999999999999999999999526
# factorial has been called with n = 999999999999999999999999999999999999525
# factorial has been called with n = 999999999999999999999999999999999999524
# factorial has been called with n = 999999999999999999999999999999999999523
# factorial has been called with n = 999999999999999999999999999999999999522
# factorial has been called with n = 999999999999999999999999999999999999521
# factorial has been called with n = 999999999999999999999999999999999999520
# factorial has been called with n = 999999999999999999999999999999999999519
# factorial has been called with n = 999999999999999999999999999999999999518
# factorial has been called with n = 999999999999999999999999999999999999517
# factorial has been called with n = 999999999999999999999999999999999999516
# factorial has been called with n = 999999999999999999999999999999999999515
# factorial has been called with n = 999999999999999999999999999999999999514
# factorial has been called with n = 999999999999999999999999999999999999513
# factorial has been called with n = 999999999999999999999999999999999999512
# factorial has been called with n = 999999999999999999999999999999999999511
# factorial has been called with n = 999999999999999999999999999999999999510
# factorial has been called with n = 999999999999999999999999999999999999509
# factorial has been called with n = 999999999999999999999999999999999999508
# factorial has been called with n = 999999999999999999999999999999999999507
# factorial has been called with n = 999999999999999999999999999999999999506
# factorial has been called with n = 999999999999999999999999999999999999505
# factorial has been called with n = 999999999999999999999999999999999999504
# factorial has been called with n = 999999999999999999999999999999999999503
# factorial has been called with n = 999999999999999999999999999999999999502
# factorial has been called with n = 999999999999999999999999999999999999501
# factorial has been called with n = 999999999999999999999999999999999999500
# factorial has been called with n = 999999999999999999999999999999999999499
# factorial has been called with n = 999999999999999999999999999999999999498
# factorial has been called with n = 999999999999999999999999999999999999497
# factorial has been called with n = 999999999999999999999999999999999999496
# factorial has been called with n = 999999999999999999999999999999999999495
# factorial has been called with n = 999999999999999999999999999999999999494
# factorial has been called with n = 999999999999999999999999999999999999493
# factorial has been called with n = 999999999999999999999999999999999999492
# factorial has been called with n = 999999999999999999999999999999999999491
# factorial has been called with n = 999999999999999999999999999999999999490
# factorial has been called with n = 999999999999999999999999999999999999489
# factorial has been called with n = 999999999999999999999999999999999999488
# factorial has been called with n = 999999999999999999999999999999999999487
# factorial has been called with n = 999999999999999999999999999999999999486
# factorial has been called with n = 999999999999999999999999999999999999485
# factorial has been called with n = 999999999999999999999999999999999999484
# factorial has been called with n = 999999999999999999999999999999999999483
# factorial has been called with n = 999999999999999999999999999999999999482
# factorial has been called with n = 999999999999999999999999999999999999481
# factorial has been called with n = 999999999999999999999999999999999999480
# factorial has been called with n = 999999999999999999999999999999999999479
# factorial has been called with n = 999999999999999999999999999999999999478
# factorial has been called with n = 999999999999999999999999999999999999477
# factorial has been called with n = 999999999999999999999999999999999999476
# factorial has been called with n = 999999999999999999999999999999999999475
# factorial has been called with n = 999999999999999999999999999999999999474
# factorial has been called with n = 999999999999999999999999999999999999473
# factorial has been called with n = 999999999999999999999999999999999999472
# factorial has been called with n = 999999999999999999999999999999999999471
# factorial has been called with n = 999999999999999999999999999999999999470
# factorial has been called with n = 999999999999999999999999999999999999469
# factorial has been called with n = 999999999999999999999999999999999999468
# factorial has been called with n = 999999999999999999999999999999999999467
# factorial has been called with n = 999999999999999999999999999999999999466
# factorial has been called with n = 999999999999999999999999999999999999465
# factorial has been called with n = 999999999999999999999999999999999999464
# factorial has been called with n = 999999999999999999999999999999999999463
# factorial has been called with n = 999999999999999999999999999999999999462
# factorial has been called with n = 999999999999999999999999999999999999461
# factorial has been called with n = 999999999999999999999999999999999999460
# factorial has been called with n = 999999999999999999999999999999999999459
# factorial has been called with n = 999999999999999999999999999999999999458
# factorial has been called with n = 999999999999999999999999999999999999457
# factorial has been called with n = 999999999999999999999999999999999999456
# factorial has been called with n = 999999999999999999999999999999999999455
# factorial has been called with n = 999999999999999999999999999999999999454
# factorial has been called with n = 999999999999999999999999999999999999453
# factorial has been called with n = 999999999999999999999999999999999999452
# factorial has been called with n = 999999999999999999999999999999999999451
# factorial has been called with n = 999999999999999999999999999999999999450
# factorial has been called with n = 999999999999999999999999999999999999449
# factorial has been called with n = 999999999999999999999999999999999999448
# factorial has been called with n = 999999999999999999999999999999999999447
# factorial has been called with n = 999999999999999999999999999999999999446
# factorial has been called with n = 999999999999999999999999999999999999445
# factorial has been called with n = 999999999999999999999999999999999999444
# factorial has been called with n = 999999999999999999999999999999999999443
# factorial has been called with n = 999999999999999999999999999999999999442
# factorial has been called with n = 999999999999999999999999999999999999441
# factorial has been called with n = 999999999999999999999999999999999999440
# factorial has been called with n = 999999999999999999999999999999999999439
# factorial has been called with n = 999999999999999999999999999999999999438
# factorial has been called with n = 999999999999999999999999999999999999437
# factorial has been called with n = 999999999999999999999999999999999999436
# factorial has been called with n = 999999999999999999999999999999999999435
# factorial has been called with n = 999999999999999999999999999999999999434
# factorial has been called with n = 999999999999999999999999999999999999433
# factorial has been called with n = 999999999999999999999999999999999999432
# factorial has been called with n = 999999999999999999999999999999999999431
# factorial has been called with n = 999999999999999999999999999999999999430
# factorial has been called with n = 999999999999999999999999999999999999429
# factorial has been called with n = 999999999999999999999999999999999999428
# factorial has been called with n = 999999999999999999999999999999999999427
# factorial has been called with n = 999999999999999999999999999999999999426
# factorial has been called with n = 999999999999999999999999999999999999425
# factorial has been called with n = 999999999999999999999999999999999999424
# factorial has been called with n = 999999999999999999999999999999999999423
# factorial has been called with n = 999999999999999999999999999999999999422
# factorial has been called with n = 999999999999999999999999999999999999421
# factorial has been called with n = 999999999999999999999999999999999999420
# factorial has been called with n = 999999999999999999999999999999999999419
# factorial has been called with n = 999999999999999999999999999999999999418
# factorial has been called with n = 999999999999999999999999999999999999417
# factorial has been called with n = 999999999999999999999999999999999999416
# factorial has been called with n = 999999999999999999999999999999999999415
# factorial has been called with n = 999999999999999999999999999999999999414
# factorial has been called with n = 999999999999999999999999999999999999413
# factorial has been called with n = 999999999999999999999999999999999999412
# factorial has been called with n = 999999999999999999999999999999999999411
# factorial has been called with n = 999999999999999999999999999999999999410
# factorial has been called with n = 999999999999999999999999999999999999409
# factorial has been called with n = 999999999999999999999999999999999999408
# factorial has been called with n = 999999999999999999999999999999999999407
# factorial has been called with n = 999999999999999999999999999999999999406
# factorial has been called with n = 999999999999999999999999999999999999405
# factorial has been called with n = 999999999999999999999999999999999999404
# factorial has been called with n = 999999999999999999999999999999999999403
# factorial has been called with n = 999999999999999999999999999999999999402
# factorial has been called with n = 999999999999999999999999999999999999401
# factorial has been called with n = 999999999999999999999999999999999999400
# factorial has been called with n = 999999999999999999999999999999999999399
# factorial has been called with n = 999999999999999999999999999999999999398
# factorial has been called with n = 999999999999999999999999999999999999397
# factorial has been called with n = 999999999999999999999999999999999999396
# factorial has been called with n = 999999999999999999999999999999999999395
# factorial has been called with n = 999999999999999999999999999999999999394
# factorial has been called with n = 999999999999999999999999999999999999393
# factorial has been called with n = 999999999999999999999999999999999999392
# factorial has been called with n = 999999999999999999999999999999999999391
# factorial has been called with n = 999999999999999999999999999999999999390
# factorial has been called with n = 999999999999999999999999999999999999389
# factorial has been called with n = 999999999999999999999999999999999999388
# factorial has been called with n = 999999999999999999999999999999999999387
# factorial has been called with n = 999999999999999999999999999999999999386
# factorial has been called with n = 999999999999999999999999999999999999385
# factorial has been called with n = 999999999999999999999999999999999999384
# factorial has been called with n = 999999999999999999999999999999999999383
# factorial has been called with n = 999999999999999999999999999999999999382
# factorial has been called with n = 999999999999999999999999999999999999381
# factorial has been called with n = 999999999999999999999999999999999999380
# factorial has been called with n = 999999999999999999999999999999999999379
# factorial has been called with n = 999999999999999999999999999999999999378
# factorial has been called with n = 999999999999999999999999999999999999377
# factorial has been called with n = 999999999999999999999999999999999999376
# factorial has been called with n = 999999999999999999999999999999999999375
# factorial has been called with n = 999999999999999999999999999999999999374
# factorial has been called with n = 999999999999999999999999999999999999373
# factorial has been called with n = 999999999999999999999999999999999999372
# factorial has been called with n = 999999999999999999999999999999999999371
# factorial has been called with n = 999999999999999999999999999999999999370
# factorial has been called with n = 999999999999999999999999999999999999369
# factorial has been called with n = 999999999999999999999999999999999999368
# factorial has been called with n = 999999999999999999999999999999999999367
# factorial has been called with n = 999999999999999999999999999999999999366
# factorial has been called with n = 999999999999999999999999999999999999365
# factorial has been called with n = 999999999999999999999999999999999999364
# factorial has been called with n = 999999999999999999999999999999999999363
# factorial has been called with n = 999999999999999999999999999999999999362
# ...
# factorial has been called with n = 999999999999999999999999999999999997242
# factorial has been called with n = 999999999999999999999999999999999997241
# factorial has been called with n = 999999999999999999999999999999999997240
# factorial has been called with n = 999999999999999999999999999999999997239
# factorial has been called with n = 999999999999999999999999999999999997238
# factorial has been called with n = 999999999999999999999999999999999997237
# factorial has been called with n = 999999999999999999999999999999999997236
# factorial has been called with n = 999999999999999999999999999999999997235
# factorial has been called with n = 999999999999999999999999999999999997234
# factorial has been called with n = 999999999999999999999999999999999997233
# factorial has been called with n = 999999999999999999999999999999999997232
# factorial has been called with n = 999999999999999999999999999999999997231
# factorial has been called with n = 999999999999999999999999999999999997230
# factorial has been called with n = 999999999999999999999999999999999997229
# factorial has been called with n = 999999999999999999999999999999999997228
# factorial has been called with n = 999999999999999999999999999999999997227
# factorial has been called with n = 999999999999999999999999999999999997226
# factorial has been called with n = 999999999999999999999999999999999997225
# factorial has been called with n = 999999999999999999999999999999999997224
# factorial has been called with n = 999999999999999999999999999999999997223
# factorial has been called with n = 999999999999999999999999999999999997222
# factorial has been called with n = 999999999999999999999999999999999997221
# factorial has been called with n = 999999999999999999999999999999999997220
# factorial has been called with n = 999999999999999999999999999999999997219
# factorial has been called with n = 999999999999999999999999999999999997218
# factorial has been called with n = 999999999999999999999999999999999997217
# factorial has been called with n = 999999999999999999999999999999999997216
# factorial has been called with n = 999999999999999999999999999999999997215
# factorial has been called with n = 999999999999999999999999999999999997214
# factorial has been called with n = 999999999999999999999999999999999997213
# factorial has been called with n = 999999999999999999999999999999999997212
# factorial has been called with n = 999999999999999999999999999999999997211
# factorial has been called with n = 999999999999999999999999999999999997210
# factorial has been called with n = 999999999999999999999999999999999997209
# factorial has been called with n = 999999999999999999999999999999999997208
# factorial has been called with n = 999999999999999999999999999999999997207
# factorial has been called with n = 999999999999999999999999999999999997206
# factorial has been called with n = 999999999999999999999999999999999997205
# factorial has been called with n = 999999999999999999999999999999999997204
# factorial has been called with n = 999999999999999999999999999999999997203
# factorial has been called with n = 999999999999999999999999999999999997202
# factorial has been called with n = 999999999999999999999999999999999997201
# factorial has been called with n = 999999999999999999999999999999999997200
# factorial has been called with n = 999999999999999999999999999999999997199
# factorial has been called with n = 999999999999999999999999999999999997198
# factorial has been called with n = 999999999999999999999999999999999997197
# factorial has been called with n = 999999999999999999999999999999999997196
# factorial has been called with n = 999999999999999999999999999999999997195
# factorial has been called with n = 999999999999999999999999999999999997194
# factorial has been called with n = 999999999999999999999999999999999997193
# factorial has been called with n = 999999999999999999999999999999999997192
# factorial has been called with n = 999999999999999999999999999999999997191
# factorial has been called with n = 999999999999999999999999999999999997190
# factorial has been called with n = 999999999999999999999999999999999997189
# factorial has been called with n = 999999999999999999999999999999999997188
# factorial has been called with n = 999999999999999999999999999999999997187
# factorial has been called with n = 999999999999999999999999999999999997186
# factorial has been called with n = 999999999999999999999999999999999997185
# factorial has been called with n = 999999999999999999999999999999999997184
# factorial has been called with n = 999999999999999999999999999999999997183
# factorial has been called with n = 999999999999999999999999999999999997182
# factorial has been called with n = 999999999999999999999999999999999997181
# factorial has been called with n = 999999999999999999999999999999999997180
# factorial has been called with n = 999999999999999999999999999999999997179
# factorial has been called with n = 999999999999999999999999999999999997178
# factorial has been called with n = 999999999999999999999999999999999997177
# factorial has been called with n = 999999999999999999999999999999999997176
# factorial has been called with n = 999999999999999999999999999999999997175
# factorial has been called with n = 999999999999999999999999999999999997174
# factorial has been called with n = 999999999999999999999999999999999997173
# factorial has been called with n = 999999999999999999999999999999999997172
# factorial has been called with n = 999999999999999999999999999999999997171
# factorial has been called with n = 999999999999999999999999999999999997170
# factorial has been called with n = 999999999999999999999999999999999997169
# factorial has been called with n = 999999999999999999999999999999999997168
# factorial has been called with n = 999999999999999999999999999999999997167
# factorial has been called with n = 999999999999999999999999999999999997166
# factorial has been called with n = 999999999999999999999999999999999997165
# factorial has been called with n = 999999999999999999999999999999999997164
# factorial has been called with n = 999999999999999999999999999999999997163
# factorial has been called with n = 999999999999999999999999999999999997162
# factorial has been called with n = 999999999999999999999999999999999997161
# factorial has been called with n = 999999999999999999999999999999999997160
# factorial has been called with n = 999999999999999999999999999999999997159
# factorial has been called with n = 999999999999999999999999999999999997158
# factorial has been called with n = 999999999999999999999999999999999997157
# factorial has been called with n = 999999999999999999999999999999999997156
# factorial has been called with n = 999999999999999999999999999999999997155
# factorial has been called with n = 999999999999999999999999999999999997154
# factorial has been called with n = 999999999999999999999999999999999997153
# factorial has been called with n = 999999999999999999999999999999999997152
# factorial has been called with n = 999999999999999999999999999999999997151
# factorial has been called with n = 999999999999999999999999999999999997150
# factorial has been called with n = 999999999999999999999999999999999997149
# factorial has been called with n = 999999999999999999999999999999999997148
# factorial has been called with n = 999999999999999999999999999999999997147
# factorial has been called with n = 999999999999999999999999999999999997146
# factorial has been called with n = 999999999999999999999999999999999997145
# factorial has been called with n = 999999999999999999999999999999999997144
# factorial has been called with n = 999999999999999999999999999999999997143
# factorial has been called with n = 999999999999999999999999999999999997142
# factorial has been called with n = 999999999999999999999999999999999997141
# factorial has been called with n = 999999999999999999999999999999999997140
# factorial has been called with n = 999999999999999999999999999999999997139
# factorial has been called with n = 999999999999999999999999999999999997138
# factorial has been called with n = 999999999999999999999999999999999997137
# factorial has been called with n = 999999999999999999999999999999999997136
# factorial has been called with n = 999999999999999999999999999999999997135
# factorial has been called with n = 999999999999999999999999999999999997134
# factorial has been called with n = 999999999999999999999999999999999997133
# factorial has been called with n = 999999999999999999999999999999999997132
# factorial has been called with n = 999999999999999999999999999999999997131
# factorial has been called with n = 999999999999999999999999999999999997130
# factorial has been called with n = 999999999999999999999999999999999997129
# factorial has been called with n = 999999999999999999999999999999999997128
# factorial has been called with n = 999999999999999999999999999999999997127
# factorial has been called with n = 999999999999999999999999999999999997126
# factorial has been called with n = 999999999999999999999999999999999997125
# factorial has been called with n = 999999999999999999999999999999999997124
# factorial has been called with n = 999999999999999999999999999999999997123
# factorial has been called with n = 999999999999999999999999999999999997122
# factorial has been called with n = 999999999999999999999999999999999997121
# factorial has been called with n = 999999999999999999999999999999999997120
# factorial has been called with n = 999999999999999999999999999999999997119
# factorial has been called with n = 999999999999999999999999999999999997118
# factorial has been called with n = 999999999999999999999999999999999997117
# factorial has been called with n = 999999999999999999999999999999999997116
# factorial has been called with n = 999999999999999999999999999999999997115
# factorial has been called with n = 999999999999999999999999999999999997114
# factorial has been called with n = 999999999999999999999999999999999997113
# factorial has been called with n = 999999999999999999999999999999999997112
# factorial has been called with n = 999999999999999999999999999999999997111
# factorial has been called with n = 999999999999999999999999999999999997110
# factorial has been called with n = 999999999999999999999999999999999997109
# factorial has been called with n = 999999999999999999999999999999999997108
# factorial has been called with n = 999999999999999999999999999999999997107
# factorial has been called with n = 999999999999999999999999999999999997106
# factorial has been called with n = 999999999999999999999999999999999997105
# factorial has been called with n = 999999999999999999999999999999999997104
# factorial has been called with n = 999999999999999999999999999999999997103
# factorial has been called with n = 999999999999999999999999999999999997102
# factorial has been called with n = 999999999999999999999999999999999997101
# factorial has been called with n = 999999999999999999999999999999999997100
# factorial has been called with n = 999999999999999999999999999999999997099
# factorial has been called with n = 999999999999999999999999999999999997098
# factorial has been called with n = 999999999999999999999999999999999997097
# factorial has been called with n = 999999999999999999999999999999999997096
# factorial has been called with n = 999999999999999999999999999999999997095
# factorial has been called with n = 999999999999999999999999999999999997094
# factorial has been called with n = 999999999999999999999999999999999997093
# factorial has been called with n = 999999999999999999999999999999999997092
# factorial has been called with n = 999999999999999999999999999999999997091
# factorial has been called with n = 999999999999999999999999999999999997090
# factorial has been called with n = 999999999999999999999999999999999997089
# factorial has been called with n = 999999999999999999999999999999999997088
# factorial has been called with n = 999999999999999999999999999999999997087
# factorial has been called with n = 999999999999999999999999999999999997086
# factorial has been called with n = 999999999999999999999999999999999997085
# factorial has been called with n = 999999999999999999999999999999999997084
# factorial has been called with n = 999999999999999999999999999999999997083
# factorial has been called with n = 999999999999999999999999999999999997082
# factorial has been called with n = 999999999999999999999999999999999997081
# factorial has been called with n = 999999999999999999999999999999999997080
# factorial has been called with n = 999999999999999999999999999999999997079
# factorial has been called with n = 999999999999999999999999999999999997078
# factorial has been called with n = 999999999999999999999999999999999997077
# factorial has been called with n = 999999999999999999999999999999999997076
# factorial has been called with n = 999999999999999999999999999999999997075
# factorial has been called with n = 999999999999999999999999999999999997074
# factorial has been called with n = 999999999999999999999999999999999997073
# factorial has been called with n = 999999999999999999999999999999999997072
# factorial has been called with n = 999999999999999999999999999999999997071
# factorial has been called with n = 999999999999999999999999999999999997070
# factorial has been called with n = 999999999999999999999999999999999997069
# factorial has been called with n = 999999999999999999999999999999999997068
# factorial has been called with n = 999999999999999999999999999999999997067
# factorial has been called with n = 999999999999999999999999999999999997066
# factorial has been called with n = 999999999999999999999999999999999997065
# factorial has been called with n = 999999999999999999999999999999999997064
# factorial has been called with n = 999999999999999999999999999999999997063
# factorial has been called with n = 999999999999999999999999999999999997062
# factorial has been called with n = 999999999999999999999999999999999997061
# factorial has been called with n = 999999999999999999999999999999999997060
# factorial has been called with n = 999999999999999999999999999999999997059
# factorial has been called with n = 999999999999999999999999999999999997058
# factorial has been called with n = 999999999999999999999999999999999997057
# factorial has been called with n = 999999999999999999999999999999999997056
# factorial has been called with n = 999999999999999999999999999999999997055
# factorial has been called with n = 999999999999999999999999999999999997054
# factorial has been called with n = 999999999999999999999999999999999997053
# factorial has been called with n = 999999999999999999999999999999999997052
# factorial has been called with n = 999999999999999999999999999999999997051
# factorial has been called with n = 999999999999999999999999999999999997050
# factorial has been called with n = 999999999999999999999999999999999997049
# factorial has been called with n = 999999999999999999999999999999999997048
# factorial has been called with n = 999999999999999999999999999999999997047
# factorial has been called with n = 999999999999999999999999999999999997046
# factorial has been called with n = 999999999999999999999999999999999997045
# factorial has been called with n = 999999999999999999999999999999999997044
# factorial has been called with n = 999999999999999999999999999999999997043
# factorial has been called with n = 999999999999999999999999999999999997042
# factorial has been called with n = 999999999999999999999999999999999997041
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-31-4835ca300519> in <module>()
# ----> 1 fact(1000000000000000000000000000000000000000)
#
# <ipython-input-24-9a987b9ec55a> in fact(n)
#       4         return 1
#       5     else:
# ----> 6         res = n * fact(n - 1)
#       7         print("intermediate result for ", n, " * fact(", n - 1, "): ", res)
#       8         return res
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-24-9a987b9ec55a> in fact(n)
#       4         return 1
#       5     else:
# ----> 6         res = n * fact(n - 1)
#       7         print("intermediate result for ", n, " * fact(", n - 1, "): ", res)
#       8         return res
#
# RecursionError: maximum recursion depth exceeded in comparison

# %% [markdown]
# 解决递归调用栈溢出的方法是通过**尾递归优化**，事实上尾递归和循环的效果是一样的，所以，把循环看成是一种特殊的尾递归函数也是可以的。
# 尾递归是指，在函数返回的时候，调用自身本身，并且，`return` 语句不能包含表达式。这样，编译器或者解释器就可以把尾递归做优化，使递归本身无论调用多少次，都只占用一个栈帧，不会出现栈溢出的情况。
# 上面的fact(n)函数由于 `return n * fact(n - 1)` 引入了乘法表达式，所以就不是尾递归了。要改成尾递归方式，需要多一点代码，主要是要把每一步的乘积传入到递归函数中：

# %%
def fact(n): 
    return fact_iter(1, 1, n)


def fact_iter(product, count, max_):
    if count > max_: 
        return product
    return fact_iter(product * count, count + 1, max_)

# %% [markdown]
# - 使用递归函数的优点是逻辑简单清晰，缺点是过深的调用会导致栈溢出。
# - 针对尾递归优化的语言可以通过尾递归防止栈溢出。尾递归事实上和循环是等价的，没有循环语句的编程语言只能通过尾递归实现循环。
# - Python 标准的解释器没有针对尾递归做优化，任何递归函数都存在栈溢出的问题。
#
# 有一个针对尾递归优化的 decorator，可以参考源码：http://code.activestate.com/recipes/474088-tail-call-optimization-decorator/
#
# 现在，只需要使用这个 `@tail_call_optimized`，就可以顺利计算出fact(1000)：
