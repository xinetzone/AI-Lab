# %%
import numpy as np
import os
import pickle


import tensorflow as tf

import keras
from keras import layers
from keras.layers import Input, merge,Add,Average, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.initializers import glorot_uniform
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
from keras.models import load_model
from keras.models import model_from_json
from keras.utils import np_utils 
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from keras.utils.training_utils import multi_gpu_model
from keras.utils import to_categorical
from keras import optimizers
from keras import regularizers

os.environ["PATH"] += os.pathsep + '~/anaconda3/lib/bin/pydot/'
os.environ["PATH"] += os.pathsep + '~/anaconda3/lib/bin/graphviz/'
import pydot
import scipy.misc
from matplotlib.pyplot import imshow
from IPython.display import SVG
import matplotlib.pyplot as plt
# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)
# Out:
# Using CNTK backend
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\keras\backend\cntk_backend.py:21: UserWarning: CNTK backend warning: GPU is not detected. CNTK's CPU version is not fully optimized,please run with GPU to get better performance.
#   'CNTK backend warning: GPU is not detected. '
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7110ab696cee> in <module>()
#      29 os.environ["PATH"] += os.pathsep + '~/anaconda3/lib/bin/pydot/'
#      30 os.environ["PATH"] += os.pathsep + '~/anaconda3/lib/bin/graphviz/'
# ---> 31 import pydot
#      32 import scipy.misc
#      33 from matplotlib.pyplot import imshow
#
# ModuleNotFoundError: No module named 'pydot'

# %%
#LIsting available devices 

from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

# %%
#Using AWS p2 instance with 1 gpu and 4 cpus 
config = tf.ConfigProto( device_count = {'GPU': 1 , 'CPU': 4} ) 
sess = tf.Session(config=config) 
keras.backend.set_session(sess)

# %%
X_train = np.load('X_train.npy')
Y_train = np.load('Y_train.npy')
X_test = np.load('X_test.npy')
Y_test = np.load('Y_test.npy')

#One hot encoding Y 
Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print('Shape of X train: ',X_train.shape)
print('Shape of Y train: ',Y_train.shape)
print('Shape of X test: ',X_test.shape)
print('Shape of Y test: ',Y_test.shape)
# Out:
# Shape of X test:  (10000, 32, 32, 3)
# Shape of Y test:  (10000, 10)

# %%
def join_layer(*signals_to_join,ldrop_prob=0):
    
    '''
    Input: 
            signals_to_join - Variable number of tensor signals to join at
                              layer depending on where in the network the 
                              join layer function is called and whether
                              dropout is enabled.For example, the number 
                              of signals to join at the end of a fractal
                              block with number of columns = 4 would be 4 
                              (without global/local dropout)
          
            ldrop_prob - local dropout probability - 15% for all signals 
                         at every join layer. We need to make sure at least
                         one signal survives in each join layer 
            
                              
    Output:
            The merged output signal after implementing local dropout
    
    '''    
   
    #Packing all signals in a list 

    list_of_signals = [signal for signal in signals_to_join]

    #Probability that an input signal is not dropped 
    lkeep_prob = 1-ldrop_prob 
    
    #Making a list of signals to be added by incorporating local 
    #drop path while also ensuring that at least one path survives
    rand = np.random.uniform(low=0.0, high=1.0)
    signals_survived = [signal for signal in signals_to_join if rand<= lkeep_prob]
   
    #If all signals have been dropped 
    if len(signals_survived)==0:
        
        #To ensure that at least one path survives we randomly
        #select a single signal and pass it on to merge 
        rand_signal_index = np.random.randint(len(list_of_signals))
        
        #Using the randomly selected signal and making a list 
        #To pass it onto the keras method to average
        signals_survived = list_of_signals[rand_signal_index]
        return signals_survived
    
    #The paper implements the join layer by taking element wise average
    out = Average()(signals_survived)
    
    return out

# %% [markdown]
# ## Fractal Block

# %%
def basic_conv(X_inp,f_number,f_size):
    '''
    Basic Convolutional layer
    '''
    
    X = Conv2D(filters = f_number, kernel_size = (f_size, f_size), strides = (1,1), padding = 'same',kernel_initializer ='he_normal',kernel_regularizer=l2(1e-4))(X_inp)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)
    
    return X

def fractal_block(Z,f_number,f_size):
    
    '''
    Input:
            Z - input feature vector 
            C - number of columns in a fractal block 
            filter_size - size of the kernel for convolution in a block
            filter_number - number of filter channels for all convolutions in a block\
           
      
    Output:
            A - Output of fractal block 
    '''
    #A fractal block with 4 columns 
    X_keep1 = Z
    X_keep2 = Z
    X_keeplast = Z
    A = basic_conv(Z,f_number,f_size)
    A = basic_conv(A,f_number,f_size)
    X_keep1 = basic_conv(X_keep1,f_number,f_size)
    A = join_layer(X_keep1,A)
    X_keep3 = A
    A = basic_conv(A,f_number,f_size)
    A = basic_conv(A,f_number,f_size)
    X_keep3 = basic_conv(X_keep3,f_number,f_size)
    X_keep2 = basic_conv(X_keep2,f_number,f_size)
    J = join_layer(A,X_keep3,X_keep2)

    X_keep1 = J
    X_keep2 = J
    A = basic_conv(J,f_number,f_size)
    A = basic_conv(A,f_number,f_size)
    X_keep1 = basic_conv(X_keep1,f_number,f_size)
    A = join_layer(X_keep1,A)
    X_keep3 = A
    A = basic_conv(A,f_number,f_size)
    A = basic_conv(A,f_number,f_size)
    X_keep3 = basic_conv(X_keep3,f_number,f_size)
    X_keep2 = basic_conv(X_keep2,f_number,f_size)
    X_keeplast = basic_conv(X_keeplast,f_number,f_size)
    A = join_layer(A,X_keep3,X_keep2,X_keeplast)

    return A

# %%
def FractalNet(input_shape = (32, 32, 3), classes = 10): 
    
    '''
    Input:
            input_shape - the shape of the input image 
            classes - number of classes 
            B - number of blocks in the fractal net 

    Output:
            A keras model instance 
            
    '''
    
    #Defining input shape and converting into a keras input tensor
    X_input = Input(input_shape)
    X = X_input
    
    #Block 1 
    X = fractal_block(X,16,3)
    X = MaxPooling2D(pool_size = (2,2), name='max_pool1')(X)
    
    #Block 2 
    X = fractal_block(X,32,3)
    X=MaxPooling2D(pool_size = (2,2), name='max_pool2')(X)
    
    #Block 3 
    X = fractal_block(X,64,3)
    X=MaxPooling2D(pool_size = (2,2), name='max_pool3')(X)
    
#     #Block 4 
#     X = fractal_block(X,512,3)
#     X=MaxPooling2D(pool_size = (2,2), name='max_pool4')(X)
    
    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer ='he_normal')(X)
    
    model = Model(inputs = X_input, outputs = X, name='FractalNet')
    return model

# %%
model = FractalNet(input_shape = (32, 32, 3), classes = 10)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None,
0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 32)   9248        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 32)   128         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 32)   128         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 32)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_7 (Average)             (None, 16, 16, 32)   0           activation_25[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 32)   9248        average_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 32)   128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 32)   9248        activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 32)   9248        average_7[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 32)   9248        average_6[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 32)   4640        max_pool1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 32)   128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 32)   128         conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 32)   128         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 32)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 32)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 32)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# average_8 (Average)             (None, 16, 16, 32)   0           activation_27[0][0]
#                                                                  activation_28[0][0]
#                                                                  activation_29[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# max_pool2 (MaxPooling2D)        (None, 8, 8, 32)     0           average_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 64)     18496       max_pool2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 64)     256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 64)     0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 64)     18496       max_pool2[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 64)     36928       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 64)     256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 64)     256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 8, 8, 64)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 64)     0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# average_9 (Average)             (None, 8, 8, 64)     0           activation_33[0][0]
#                                                                  activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 64)     36928       average_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 64)     256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 8, 8, 64)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 64)     36928       activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 64)     36928       average_9[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 64)     18496       max_pool2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 64)     256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 8, 64)     256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 64)     256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 8, 8, 64)     0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 8, 8, 64)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 64)     0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_10 (Average)            (None, 8, 8, 64)     0           activation_35[0][0]
#                                                                  activation_36[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 64)     36928       average_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 64)     256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 64)     0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 64)     36928       average_10[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 64)     36928       activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 64)     256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 64)     256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 8, 8, 64)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 8, 8, 64)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# average_11 (Average)            (None, 8, 8, 64)     0           activation_40[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 64)     36928       average_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 64)     256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8, 8, 64)     0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 64)     36928       activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 64)     36928       average_11[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 64)     36928       average_10[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 64)     18496       max_pool2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 64)     256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8, 8, 64)     256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 8, 8, 64)     256         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 64)     256         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 8, 8, 64)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 8, 8, 64)     0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 64)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 64)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# average_12 (Average)            (None, 8, 8, 64)     0           activation_42[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# max_pool3 (MaxPooling2D)        (None, 4, 4, 64)     0           average_12[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1024)         0           max_pool3[0][0]
# __________________________________________________________________________________________________
# fc10 (Dense)                    (None, 10)           10250       flatten_1[0][0]
# ==================================================================================================
# Total params: 644,762
# Trainable params: 641,402
# Non-trainable params: 3,360
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='fractalnet_model.png', show_shapes=True, show_layer_names=False)
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
class MyCallbackFunction(keras.callbacks.Callback):

    def on_train_begin(self, logs={} ):
        #Learning rate schedule
        #Changed after 80,120,160,180 epochs 
        
        self.k = 0
        
        #Keeping track of number of epochs 
        self.epoch_n = 0 
        
        #Learning rates list
        self.lrs_in_epoch = [1e-4,1e-5,1e-6,1e-7]
        
        #History of losses and accuracies 
        self.loss = []
        self.val_acc =[]
        self.train_acc = []

        #monitoring improvement of validation accuracy 
        #Setting initial val acc to negative infinity 
        self.val_prev = -float("inf")
        
    def on_batch_end(self, batch, logs={}):
        self.loss.append(logs.get('loss'))

    def on_epoch_end(self, epoch, logs):
        
        #Storing validation and training accuracies of the epoch
        self.val_acc.append(logs.get('val_acc'))
        self.train_acc.append(logs.get('acc'))

        #Incrementing number of epochs 
        self.epoch_n +=1
        
        #Saving model if val acc improves compared to best previous epoch
        if logs.get('val_acc') > self.val_prev: 
            print('Validation accuracy improved! Saving model. \n')
        
            #Saving model 
            json_string = model.to_json()
            with open('fractalnet_models/model_epoch'+str(self.epoch_n)+'_json.pkl', 'wb') as m:
                pickle.dump(json_string, m)
            model.save_weights('fractalnet_models/model_epoch'+str(self.epoch_n)+'_weights.h5')
            
            #Saving current better val acc to compare with next epoch's val acc
            self.val_prev = logs.get('val_acc')
            
        else: 
            print('Validation accuracy did not improve. Moving on. \n')
        
        #Printing learning rate 
        LR = K.get_value(self.model.optimizer.lr)
        print('Current learning rate: ',LR )

            
        #Adjusting learning rate     
        if self.epoch_n == 80 or self.epoch_n == 120 or self.epoch_n == 160 or self.epoch_n == 180:
            K.set_value(self.model.optimizer.lr,self.lrs_in_epoch[self.k])
            self.k+=1
    

#Main 

#Creating an instance of the callback function
history_cb = MyCallbackFunction()

# %%
#Initial learning rate and optimizer
initial_rate = 0.001
opt = optimizers.Adam(lr=initial_rate)

#Compiling model
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])


#Data generator for training data  
#No data generator is used for testing data
data_generator = ImageDataGenerator(
                featurewise_center=False,
                samplewise_center = False,
                featurewise_std_normalization = False,
                samplewise_std_normalization=False,
                zca_whitening= False,
                rotation_range=0,
                width_shift_range=0.1,
                height_shift_range=0.1,
                horizontal_flip=True,
                vertical_flip=False,
                )

print('Real time data augmentation enabled.\n')
print('Initial Learning rate: ',initial_rate)

#Fitting model
model.fit_generator(data_generator.flow(X_train, Y_train, batch_size=32),
                    validation_data = (X_test, Y_test),
                    epochs = 200, 
                    steps_per_epoch = data_generator.flow(X_train,Y_train,batch_size=32).n/32,
                    callbacks = [history_cb])


#Model evaluation 
preds = model.evaluate(X_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))

#Plotting loss and accuracies
plt.plot(history_cb.loss)
plt.show()

plt.plot(history_cb.train_acc)
plt.show()

plt.plot(history_cb.val_acc)
plt.show()
# Out:
# Real time data augmentation enabled.
#
# Initial Learning rate:  0.001
# Epoch 1/200
# 1563/1562 [==============================] - 152s 97ms/step - loss: 1.5868 - acc: 0.5168 - val_loss: 1.2121 - val_acc: 0.6622
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 2/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 1.1150 - acc: 0.6895 - val_loss: 1.0053 - val_acc: 0.7310
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 3/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.9511 - acc: 0.7425 - val_loss: 0.8636 - val_acc: 0.7778
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 4/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.8611 - acc: 0.7727 - val_loss: 0.8033 - val_acc: 0.7972
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 5/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.8007 - acc: 0.7947 - val_loss: 0.7899 - val_acc: 0.7991
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 6/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.7482 - acc: 0.8108 - val_loss: 0.7536 - val_acc: 0.8099
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 7/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.7162 - acc: 0.8217 - val_loss: 0.7330 - val_acc: 0.8209
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 8/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.6962 - acc: 0.8309 - val_loss: 0.7024 - val_acc: 0.8306
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 9/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.6733 - acc: 0.8385 - val_loss: 0.6847 - val_acc: 0.8396
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 10/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.6646 - acc: 0.8432 - val_loss: 0.6782 - val_acc: 0.8411
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 11/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.6477 - acc: 0.8514 - val_loss: 0.6444 - val_acc: 0.8525
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 12/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.6334 - acc: 0.8554 - val_loss: 0.6900 - val_acc: 0.8393
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 13/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.6219 - acc: 0.8599 - val_loss: 0.6689 - val_acc: 0.8442
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 14/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.6126 - acc: 0.8648 - val_loss: 0.6547 - val_acc: 0.8514
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 15/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.6059 - acc: 0.8667 - val_loss: 0.6504 - val_acc: 0.8545
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 16/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5949 - acc: 0.8705 - val_loss: 0.6315 - val_acc: 0.8587
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 17/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5882 - acc: 0.8737 - val_loss: 0.6287 - val_acc: 0.8644
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 18/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5846 - acc: 0.8754 - val_loss: 0.6379 - val_acc: 0.8608
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 19/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5796 - acc: 0.8765 - val_loss: 0.6210 - val_acc: 0.8668
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 20/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5742 - acc: 0.8772 - val_loss: 0.6450 - val_acc: 0.8585
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 21/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5655 - acc: 0.8810 - val_loss: 0.6299 - val_acc: 0.8656
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 22/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5649 - acc: 0.8822 - val_loss: 0.6242 - val_acc: 0.8680
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 23/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5528 - acc: 0.8855 - val_loss: 0.6259 - val_acc: 0.8637
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 24/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5567 - acc: 0.8856 - val_loss: 0.6344 - val_acc: 0.8618
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 25/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5514 - acc: 0.8860 - val_loss: 0.6201 - val_acc: 0.8686
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 26/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5475 - acc: 0.8879 - val_loss: 0.6337 - val_acc: 0.8649
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 27/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5480 - acc: 0.8881 - val_loss: 0.6248 - val_acc: 0.8678
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 28/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5427 - acc: 0.8891 - val_loss: 0.6000 - val_acc: 0.8703
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 29/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5421 - acc: 0.8908 - val_loss: 0.6058 - val_acc: 0.8701
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 30/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5432 - acc: 0.8903 - val_loss: 0.6102 - val_acc: 0.8724
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 31/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5323 - acc: 0.8943 - val_loss: 0.6153 - val_acc: 0.8681
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 32/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5326 - acc: 0.8931 - val_loss: 0.6107 - val_acc: 0.8725
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 33/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5283 - acc: 0.8960 - val_loss: 0.5985 - val_acc: 0.8779
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 34/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5310 - acc: 0.8951 - val_loss: 0.6239 - val_acc: 0.8699
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 35/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5248 - acc: 0.8958 - val_loss: 0.6236 - val_acc: 0.8708
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 36/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5252 - acc: 0.8964 - val_loss: 0.6107 - val_acc: 0.8746
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 37/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5236 - acc: 0.8976 - val_loss: 0.6109 - val_acc: 0.8753
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 38/200
# 1563/1562 [==============================] - 146s 93ms/step - loss: 0.5221 - acc: 0.8967 - val_loss: 0.6172 - val_acc: 0.8714
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 39/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5227 - acc: 0.8972 - val_loss: 0.6005 - val_acc: 0.8787
# Validation accuracy improved! Saving model.
#
# Current learning rate:  0.001
# Epoch 40/200
# 1563/1562 [==============================] - 146s 93ms/step - loss: 0.5157 - acc: 0.8988 - val_loss: 0.6082 - val_acc: 0.8750
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 41/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5155 - acc: 0.8990 - val_loss: 0.6142 - val_acc: 0.8694
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 42/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.5109 - acc: 0.9014 - val_loss: 0.5915 - val_acc: 0.8748
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  0.001
# Epoch 43/200
# 1563/1562 [==============================] - 146s 93ms/step - loss: 0.5086 - acc: 0.9008 - val_loss: 0.5928 - val_acc: 0.8768
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:
200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.3655 - acc: 0.9468 - val_loss: 0.4981 - val_acc: 0.9068
# Validation accuracy improved! Saving model.
#
# Current learning rate:  1e-04
# Epoch 83/200
# 1563/1562 [==============================] - 146s 93ms/step - loss: 0.3509 - acc: 0.9511 - val_loss: 0.4923 - val_acc: 0.9068
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 84/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.3373 - acc: 0.9539 - val_loss: 0.4817 - val_acc: 0.9115
# Validation accuracy improved! Saving model.
#
# Current learning rate:  1e-04
# Epoch 85/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.3277 - acc: 0.9561 - val_loss: 0.4780 - val_acc: 0.9102
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 86/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.3184 - acc: 0.9581 - val_loss: 0.4744 - val_acc: 0.9117
# Validation accuracy improved! Saving model.
#
# Current learning rate:  1e-04
# Epoch 87/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.3081 - acc: 0.9611 - val_loss: 0.4780 - val_acc: 0.9081
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 88/200
# 1563/1562 [==============================] - 146s 93ms/step - loss: 0.3031 - acc: 0.9606 - val_loss: 0.4683 - val_acc: 0.9101
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 89/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2966 - acc: 0.9611 - val_loss: 0.4653 - val_acc: 0.9115
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 90/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2884 - acc: 0.9640 - val_loss: 0.4608 - val_acc: 0.9121
# Validation accuracy improved! Saving model.
#
# Current learning rate:  1e-04
# Epoch 91/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2842 - acc: 0.9644 - val_loss: 0.4647 - val_acc: 0.9106
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 92/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2756 - acc: 0.9666 - val_loss: 0.4579 - val_acc: 0.9121
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 93/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2714 - acc: 0.9664 - val_loss: 0.4585 - val_acc: 0.9122
# Validation accuracy improved! Saving model.
#
# Current learning rate:  1e-04
# Epoch 94/200
# 1563/1562 [==============================] - 146s 93ms/step - loss: 0.2661 - acc: 0.9676 - val_loss: 0.4575 - val_acc: 0.9122
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 95/200
# 1563/1562 [==============================] - 146s 93ms/step - loss: 0.2609 - acc: 0.9688 - val_loss: 0.4557 - val_acc: 0.9124
# Validation accuracy improved! Saving model.
#
# Current learning rate:  1e-04
# Epoch 96/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2577 - acc: 0.9686 - val_loss: 0.4516 - val_acc: 0.9141
# Validation accuracy improved! Saving model.
#
# Current learning rate:  1e-04
# Epoch 97/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2554 - acc: 0.9682 - val_loss: 0.4580 - val_acc: 0.9111
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 98/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2491 - acc: 0.9701 - val_loss: 0.4524 - val_acc: 0.9106
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 99/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2454 - acc: 0.9705 - val_loss: 0.4512 - val_acc: 0.9141
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 100/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2388 - acc: 0.9721 - val_loss: 0.4514 - val_acc: 0.9147
# Validation accuracy improved! Saving model.
#
# Current learning rate:  1e-04
# Epoch 101/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2357 - acc: 0.9724 - val_loss: 0.4490 - val_acc: 0.9139
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-04
# Epoch 102/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2329 - acc: 0.9736 - val_loss: 0.4496 - val_acc: 0.9157
# Validation accuracy improved! Saving model.
#
# Current learning rate:  1e-04
# Epoch 103/200
# 1563/1562 [==============================] - 145s 93ms/step - loss: 0.2302 - acc: 0.9735 - val_loss: 0.4429 - val_acc: 0.9147
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-07
# Epoch 200/200
# 1563/1562 [==============================] - 146s 94ms/step - loss: 0.1556 - acc: 0.9883 - val_loss: 0.4322 - val_acc: 0.9189
# Validation accuracy did not improve. Moving on.
#
# Current learning rate:  1e-07
# 10000/10000 [==============================] - 7s 662us/step
# Loss = 0.4321953187942505
# Test Accuracy = 0.9189

# %%
plt.plot(history_cb.loss)
plt.grid()
plt.title('Loss vs iteration')
plt.xlabel('No. of iterations')
plt.ylabel('Loss')
plt.show()

plt.plot(history_cb.train_acc)
plt.grid()
plt.title('Training accuracy')
plt.xlabel('Epoch')
plt.ylabel('Training accuracy')
plt.show()

plt.plot(history_cb.val_acc)
plt.grid()
plt.title('Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Validation accuracy')
plt.show()

# %%
#Saving histories 
with open('fractalnet_models/loss.pkl', 'wb') as m:
                pickle.dump(history_cb.loss, m)
        
with open('fractalnet_models/valacc.pkl', 'wb') as mo:
        pickle.dump(history_cb.val_acc, mo)
        
with open('fractalnet_models/trainacc.pkl', 'wb') as mu:
                pickle.dump(history_cb.train_acc, mu)

# %%
#Loading best fractalnet model 
json_string = pickle.load( open( "model_epoch157_json.pkl", "rb" ) )
model = model_from_json(json_string)
model.load_weights('model_epoch157_weights.h5')

# %%
"""
Code from http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html 

"""
import sklearn
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.1f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Prediction test set 
p = model.predict(X_test)
#Converting from one hot back to integers
y_pred = [np.where(r==np.max(r))[0][0] for r in p]

#Ground truth
a = Y_test
#Converting from one hot back to integers
y_true = [np.where(r==1)[0][0] for r in a ]

#Caulculating confusion matrix 
cnf_matrix = confusion_matrix(y_true,y_pred)
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck'],normalize=True,
                      title='Normalized confusion matrix')

plt.show()


print(' Testing accuracy: ')
pr = model.predict(X_test)
ypred = [np.where(r==np.max(r))[0][0] for r in pr]
good = [1 for i in range(0,len(ypred)) if y_true[i]==ypred[i]]
accuracy = len(good)/len(ypred)
print(accuracy)
# Out:
# Normalized confusion matrix
# [[0.92 0.   0.02 0.01 0.   0.   0.   0.01 0.03 0.02]
#  [0.   0.95 0.   0.   0.   0.   0.   0.   0.01 0.04]
#  [0.02 0.   0.89 0.02 0.03 0.01 0.02 0.01 0.01 0.  ]
#  [0.01 0.   0.02 0.84 0.01 0.05 0.03 0.01 0.01 0.01]
#  [0.01 0.   0.01 0.01 0.93 0.01 0.   0.02 0.   0.  ]
#  [0.   0.   0.02 0.07 0.02 0.86 0.01 0.01 0.   0.  ]
#  [0.01 0.   0.01 0.03 0.01 0.01 0.94 0.   0.   0.01]
#  [0.01 0.   0.01 0.01 0.01 0.01 0.   0.95 0.   0.  ]
#  [0.02 0.01 0.   0.   0.   0.   0.   0.   0.96 0.01]
#  [0.01 0.03 0.   0.   0.   0.   0.   0.   0.01 0.96]]
#  Testing accuracy:
# 0.9199
