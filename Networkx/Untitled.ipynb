# %%
import networkx as nx
import numpy as np
# %matplotlib inline

# %%
G = nx.DiGraph()
G.add_edges_from([('Class', f'$X_%s$'%i) for i in range(7)])

pos = nx.spring_layout(G)
nx.draw(G)
plt.show()
